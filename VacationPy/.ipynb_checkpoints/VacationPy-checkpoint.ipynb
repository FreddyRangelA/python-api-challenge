# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
output_weather_csv=pd.read_csv('weather_CSV/weather_data.csv') 
city_df=pd.DataFrame(output_weather_csv)
city_df
# Out:
#      Unnamed: 0              City      Lat       lng  Max Temp  Humidity  \
# 0             0      punta arenas -53.1500  -70.9167     46.00        45
# 1             1           emerald -23.5333  148.1667     93.20        36
# 2             2        phan thiet  10.9333  108.1000     87.75        52
# 3             3             kieta  -6.2167  155.6333     82.47        71
# 4             4      norman wells  65.2820 -126.8329     -4.00        65
# ..          ...               ...      ...       ...       ...       ...
# 570         570         tuatapere -46.1333  167.6833     60.21        75
# 571         571           atambua  -9.1061  124.8925     80.51        81
# 572         572  puerto maldonado -12.6000  -69.1833     70.61        97
# 573         573          carolina  18.3808  -65.9574     73.40        94
# 574         574            lyuban  52.7985   28.0048     33.12        93
#
#      Cloudiness  Wind Speed Country        Date
# 0            20       19.57      CL  1615616962
# 1            94        8.05      AU  1615617088
# 2            14       14.97      VN  1615617088
# 3           100        6.26      PG  1615617088
# 4            75        9.22      CA  1615617089
# ..          ...         ...     ...         ...
# 570           0        2.57      NZ  1615617250
# 571          99        2.04      ID  1615617250
# 572         100        1.50      PE  1615617250
# 573          40        4.61      PR  1615617251
# 574           1        9.98      BY  1615617251
#
# [575 rows x 10 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
#configure gmaps.
gmaps.configure(api_key=g_key)

#adding the location and longitud for the fig

locations= city_df[["Lat","lng"]]
#print(locations)
weight_humidity=city_df["Humidity"].astype(float)
#print(weight)

#inserting the map
fig=gmaps.figure()

#creating the heat leyer
heat_layer=gmaps.heatmap_layer(locations, weights=weight_humidity, dissipating=False, max_intensity=30,point_radius=3)

#adding the layer
fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
#getting the cities with values lower 80 but higher that 70, wind speeds less that 10 mph and zero cloudiness
#values lower 80
ideal_city_80_df=city_df.loc[(city_df["Max Temp"] < 80), :]
#higher that 70
ideal_city_70r_df=ideal_city_80_df.loc[(ideal_city_80_df["Max Temp"] >70), :]
#speeds less that 10 mph
wind_speed_df=ideal_city_70r_df.loc[(ideal_city_70r_df["Wind Speed"]<10),:]
wind_speed_df.reset_index()
del wind_speed_df['Unnamed: 0']
wind_speed_df
# Out:
#                  City      Lat       lng  Max Temp  Humidity  Cloudiness  \
# 6             limbang   4.7500  115.0000     75.20       100          75
# 10             avarua -21.2078 -159.7750     77.00        94          42
# 18          busselton -33.6500  115.3333     71.01        49           0
# 26             atuona  -9.8000 -139.0333     79.93        62         100
# 27              nauta  -4.5061  -73.5757     70.70        95          37
# ..                ...      ...       ...       ...       ...         ...
# 545         springbok -29.6643   17.8865     74.34        24          81
# 551          pimentel  -6.8367  -79.9342     72.00        85         100
# 556             rafai   4.9500   23.9167     77.54        67         100
# 572  puerto maldonado -12.6000  -69.1833     70.61        97         100
# 573          carolina  18.3808  -65.9574     73.40        94          40
#
#      Wind Speed Country        Date
# 6          2.30      MY  1615617089
# 10         3.44      CK  1615617090
# 18         3.00      AU  1615617092
# 26         3.76      PF  1615617095
# 27         1.19      PE  1615617095
# ..          ...     ...         ...
# 545        0.72      ZA  1615617242
# 551        3.00      PE  1615617244
# 556        4.12      CF  1615617246
# 572        1.50      PE  1615617250
# 573        4.61      PR  1615617251
#
# [82 rows x 9 columns]

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
#Store into variable named hotel_df.
hotel_df=wind_speed_df.copy()

hotelname= []




for i in range(len(hotel_df)):
    lat = hotel_df.iloc[i]['Lat']

    lng = hotel_df.iloc[i]['lng']
    

    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
    #Set parameters to search for hotels with 5000 meters.
    params = {
        "location":f"{lat},{lng}",
        "keyword" : "hotel",
        "types" : "hotel",
        "radius": 5000,
        "key": g_key}
    responce = requests.get(base_url, params=params)
     #Hit the Google Places API for each city's coordinates.
    hotel_json= responce.json()

    try:
        hotelname.append(hotel_json['results'][0]['name'])

    except:
        hotelname.append("Nearest hotel not found")
        
#Add a "Hotel Name" column to the DataFrame.        
hotel_df["Hotel Name"]=hotelname

#Store the first Hotel result into the DataFrame.
hotel_df
# Out:
#                  City      Lat       lng  Max Temp  Humidity  Cloudiness  \
# 551          pimentel  -6.8367  -79.9342     72.00        85         100
# 379         quelimane -17.8786   36.8883     77.00       100          75
# 317            omboue  -1.5746    9.2618     76.10        86         100
# 376          santarem  -2.4431  -54.7083     71.60       100          75
# 483          jucurutu  -6.0339  -37.0203     74.84        79           5
# 156              hilo  19.7297 -155.0900     73.40        78          20
# 395            namibe -15.1961   12.1522     74.52        86          80
# 249     alta floresta  -9.8756  -56.0861     70.23        96          87
# 146             tabuk  17.4189  121.4443     79.09        76          88
# 331       reconquista -29.1500  -59.6500     71.96        47          69
# 351             bouna   9.2667   -3.0000     75.20        45          74
# 285        morant bay  17.8815  -76.4093     77.00        73          20
# 498           cayenne   4.9333  -52.3333     73.40        94          90
# 315        coahuayana  18.7333 -103.6833     70.88        50           0
# 313        bachaquero   9.9694  -71.1494     77.09        71          18
# 125            mangai  -4.0500   19.5333     76.44        85         100
# 327          bandundu  -3.3167   17.3667     77.45        75          74
# 406            lucapa  -8.4192   20.7447     71.55        90         100
# 572  puerto maldonado -12.6000  -69.1833     70.61        97         100
# 119           mancora  -4.1078  -81.0475     78.26        73         100
# 237             alofi -19.0595 -169.9187     78.80        83          11
# 469        le vauclin  14.5452  -60.8388     75.20        78          75
# 61       puerto ayora  -0.7393  -90.3518     75.99        93           0
# 442           chicama  -7.8447  -79.1469     73.44        70           0
# 404         alyangula -13.8483  136.4192     77.00        94          75
# 10             avarua -21.2078 -159.7750     77.00        94          42
# 50              vaini -21.2000 -175.2000     75.20        94          75
# 57             talara  -4.5772  -81.2719     76.44        74          99
# 143             airai  -8.9266  125.4092     70.25        87          91
# 393     alice springs -23.7000  133.8833     75.20        78          94
# 157       east london -33.0153   27.9116     78.80        69           0
# 222          flinders -34.5833  150.8552     78.01        81          90
# 232      jacareacanga  -6.2222  -57.7528     70.47        98          13
# 120   arraial do cabo -22.9661  -42.0278     76.32        87           2
# 258             opuwo -18.0607   13.8400     76.75        49           1
# 408             bumba   2.1833   22.4667     77.86        82         100
# 370            pangai -19.8000 -174.3500     78.80        83          40
# 418             moron -34.6534  -58.6198     71.01        80          40
# 123           sechura  -5.5569  -80.8222     77.47        64         100
# 66            aconibe   1.2968   10.9369     71.71        83         100
#
#      Wind Speed Country        Date  \
# 551        3.00      PE  1615617244
# 379        6.71      MZ  1615617138
# 317        4.23      GA  1615617178
# 376        2.30      BR  1615616896
# 483        3.44      BR  1615617225
# 156        4.61      US  1615616706
# 395        1.83      AO  1615617200
# 249        0.60      BR  1615617158
# 146        7.45      PH  1615617129
# 331        3.13      AR  1615617182
# 351        4.27      CI  1615617188
# 285        3.44      JM  1615617169
# 498        2.19      GF  1615616997
# 315        3.02      MX  1615617177
# 313        3.11      VE  1615617177
# 125        1.41      CD  1615617123
# 327        3.42      CD  1615617181
# 406        1.90      AO  1615617204
# 572        1.50      PE  1615617250
# 119        4.97      PE  1615617122
# 237        2.30      NU  1615616995
# 469        8.05      MQ  1615617221
# 61         1.01      EC  1615617105
# 442        4.88      PE  1615617213
# 404        6.91      AU  1615617203
# 10         3.44      CK  1615617090
# 50         4.61      TO  1615617102
# 57         7.58      PE  1615617004
# 143        0.74      TL  1615616968
# 393        9.22      AU  1615617200
# 157        5.75      ZA  1615617002
# 222        8.01      AU  1615617150
# 232        0.34      BR  1615617153
# 120        4.79      BR  1615616970
# 258        2.57     NaN  1615617015
# 408        4.07      CD  1615617204
# 370        9.17      TO  1615617194
# 418        1.99      AR  1615617207
# 123        8.30      PE  1615617123
# 66         1.63      GQ  1615617106
#
#                                         Hotel Name
# 551                                  Garuda Hostal
# 379                 RESIDENCIAL PÉROLA - Quelimane
# 317                    Hôtel Georges Faustin Aurat
# 376                          Hotel London Santarém
# 483                             Pousada Nossa Casa
# 156                            Hilo Hawaiian Hotel
# 395                                iu Hotel Namibe
# 249                       Hotel Caleche Park Hotel
# 146                                 yKalinga Hotel
# 331                       Altavista Apart Boutique
# 351                                  GNIME'S HÔTEL
# 285                            Golden Shore Resort
# 498                 Mercure Cayenne Royal Amazonia
# 315                               Hotel Aeropuerto
# 313                        Nearest hotel not found
# 125                        Nearest hotel not found
# 327                                    Hôtel Bondo
# 406                        Nearest hotel not found
# 572                                    Wasai Hotel
# 119                    Hotel Grandmare & Bungalows
# 237                                  Taloa Heights
# 469                        Bungalows de la Prairie
# 61                         La Isla Galapagos Hotel
# 442                              Balihai Bungalows
# 404                           Groote Eylandt Lodge
# 10   Panama Apartments on the Rarotonga Beachfront
# 50                            Paradise First Hotel
# 57                         Hotel Gran Palma Talara
# 143                        Nearest hotel not found
# 393       DoubleTree by Hilton Hotel Alice Springs
# 157                              Blue Lagoon Hotel
# 222                                      The Point
# 232                                    HOTEL VIANA
# 120                        Orlanova Boutique Hotel
# 258                               Aameny Rest Camp
# 408                        Nearest hotel not found
# 370                           Ha'apai Beach Resort
# 418                           The Palm House Hotel
# 123                              Hotel Loma Dorada
# 66                         Nearest hotel not found

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "lng"]]

# %%
# Add marker layer ontop of heat map
#Plot markers on top of the heatmap.
markers_hotels= gmaps.marker_layer(locations, info_box_content=hotel_info )
fig.add_layer(markers_hotels)


# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
