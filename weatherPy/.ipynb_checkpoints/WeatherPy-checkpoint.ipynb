# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 622

# %%
url_weather="http://api.openweathermap.org/data/2.5/weather?"
url=f"{url_weather}appid={weather_api_key}&q={city}"

response=requests.get(url)
data=response.json()
data
# Out:
# {'coord': {'lon': 94.5, 'lat': 25.6667},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03d'}],
#  'base': 'stations',
#  'main': {'temp': 295.66,
#   'feels_like': 292.31,
#   'temp_min': 295.66,
#   'temp_max': 295.66,
#   'pressure': 1010,
#   'humidity': 24,
#   'sea_level': 1010,
#   'grnd_level': 834},
#  'visibility': 10000,
#  'wind': {'speed': 2.15, 'deg': 288},
#  'clouds': {'all': 35},
#  'dt': 1615364481,
#  'sys': {'country': 'IN', 'sunrise': 1615334201, 'sunset': 1615376891},
#  'timezone': 19800,
#  'id': 1259784,
#  'name': 'Phek',
#  'cod': 200}

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#checking for the URL query

count_city=1

city_data=[]
coord_lat=[]
coord_lon=[]
main_max_temp=[]
humidity=[]
cloudiness=[]
wind_speed=[]
country=[]
dt=[]

for city in cities:
    
    #retrive url and request the json file
    url_weather="http://api.openweathermap.org/data/2.5/weather?"
    query_url=f"{url_weather}appid={weather_api_key}&q={city}"
    weather_response=requests.get(query_url)
    weather_json=weather_response.json()
    
    #run loop on all cities with data needed.
    try:
        
        coord_lat.append(weather_json['coord']['lat'])
        coord_lon.append(weather_json['coord']['lon'])
        main_max_temp.append(weather_json['main']['temp_max'])
        humidity.append(weather_json['main']['humidity'])
        cloudiness.append(weather_json['clouds']['all'])
        wind_speed.append(weather_json['wind']['speed'])
        country.append(weather_json['sys']['country'])
        dt.append(weather_json['dt'])
        city_data.append(city)
        print(f"Processing Record {count_city}|{city}")
    except:
         print(f'City not found. Skipping...{city}')
            
    count_city+=1
# Out:
# Processing Record 1|manokwari
# Processing Record 2|mahebourg
# Processing Record 3|hithadhoo
# City not found. Skipping...vaitupu
# City not found. Skipping...belushya guba
# Processing Record 6|busselton
# Processing Record 7|chipinge
# Processing Record 8|fortuna
# Processing Record 9|pisco
# Processing Record 10|puerto ayora
# Processing Record 11|te anau
# Processing Record 12|ribeira grande
# Processing Record 13|burns lake
# Processing Record 14|vaini
# City not found. Skipping...nizhneyansk
# Processing Record 16|bluff
# Processing Record 17|bud
# Processing Record 18|mataura
# Processing Record 19|karratha
# City not found. Skipping...amderma
# Processing Record 21|sola
# Processing Record 22|kaeo
# Processing Record 23|hilo
# Processing Record 24|lavrentiya
# Processing Record 25|guadalajara
# Processing Record 26|kanniyakumari
# Processing Record 27|harper
# Processing Record 28|ambulu
# Processing Record 29|bathsheba
# City not found. Skipping...illoqqortoormiut
# Processing Record 31|narsaq
# Processing Record 32|mar del plata
# Processing Record 33|sitka
# Processing Record 34|saint-joseph
# Processing Record 35|rikitea
# Processing Record 36|arraial do cabo
# Processing Record 37|khatanga
# Processing Record 38|teya
# Processing Record 39|boyolangu
# Processing Record 40|thinadhoo
# City not found. Skipping...mys shmidta
# Processing Record 42|punta arenas
# Processing Record 43|tasiilaq
# Processing Record 44|chuy
# Processing Record 45|kilindoni
# City not found. Skipping...yirol
# Processing Record 47|souillac
# Processing Record 48|kodiak
# Processing Record 49|buchanan
# Processing Record 50|bethel
# Processing Record 51|victoria
# Processing Record 52|albany
# Processing Record 53|ambovombe
# Processing Record 54|castro
# Processing Record 55|san cristobal
# Processing Record 56|san andres
# Processing Record 57|elliot lake
# Processing Record 58|upernavik
# Processing Record 59|kahului
# Processing Record 60|hami
# Processing Record 61|sobolevo
# Processing Record 62|ust-tsilma
# Processing Record 63|port alfred
# Processing Record 64|kruisfontein
# Processing Record 65|hobyo
# Processing Record 66|hearst
# Processing Record 67|pihuamo
# Processing Record 68|ushuaia
# Processing Record 69|yellowknife
# Processing Record 70|jamestown
# Processing Record 71|new norfolk
# Processing Record 72|longyearbyen
# Processing Record 73|orange cove
# Processing Record 74|cape town
# Processing Record 75|norman wells
# Processing Record 76|deputatskiy
# Processing Record 77|east london
# Processing Record 78|la ronge
# Processing Record 79|surgut
# Processing Record 80|san carlos del zulia
# Processing Record 81|itanhem
# Processing Record 82|ponta do sol
# Processing Record 83|arman
# Processing Record 84|bahia honda
# Processing Record 85|cururupu
# Processing Record 86|almaznyy
# Processing Record 87|kulhudhuffushi
# Processing Record 88|kapaa
# Processing Record 89|yumen
# Processing Record 90|chara
# Processing Record 91|neuquen
# Processing Record 92|cabo san lucas
# Processing Record 93|riyadh
# Processing Record 94|lillesand
# Processing Record 95|chokurdakh
# City not found. Skipping...attawapiskat
# Processing Record 97|crixas
# City not found. Skipping...taolanaro
# Processing Record 99|galveston
# Processing Record 100|ilulissat
# Processing Record 101|esperance
# Processing Record 102|namatanai
# Processing Record 103|sangueya
# Processing Record 104|atuona
# Processing Record 105|qaanaaq
# Processing Record 106|quatre cocos
# Processing Record 107|khandyga
# Processing Record 108|digboi
# Processing Record 109|avarua
# Processing Record 110|bangassou
# Processing Record 111|bredasdorp
# Processing Record 112|quang ngai
# Processing Record 113|batagay-alyta
# Processing Record 114|hofn
# Processing Record 115|tiznit
# Processing Record 116|nanortalik
# Processing Record 117|luderitz
# Processing Record 118|altay
# Processing Record 119|manzanillo
# City not found. Skipping...lolua
# Processing Record 121|lensk
# Processing Record 122|divnomorskoye
# Processing Record 123|lhokseumawe
# Processing Record 124|safakulevo
# Processing Record 125|fort nelson
# Processing Record 126|katobu
# Processing Record 127|mae sai
# Processing Record 128|port elizabeth
# Processing Record 129|buala
# Processing Record 130|port hardy
# Processing Record 131|bambous virieux
# Processing Record 132|uarini
# Processing Record 133|touros
# Processing Record 134|sebaste
# Processing Record 135|nabire
# City not found. Skipping...barentsburg
# Processing Record 137|birin
# Processing Record 138|mount gambier
# City not found. Skipping...barbar
# Processing Record 140|bonavista
# Processing Record 141|llanera
# Processing Record 142|syasstroy
# Processing Record 143|goderich
# Processing Record 144|talnakh
# Processing Record 145|labytnangi
# City not found. Skipping...saleaula
# Processing Record 147|ponta delgada
# Processing Record 148|athmallik
# Processing Record 149|weymouth
# Processing Record 150|torbay
# Processing Record 151|constitucion
# Processing Record 152|kaitangata
# Processing Record 153|matias barbosa
# Processing Record 154|hermanus
# City not found. Skipping...sorvag
# Processing Record 156|butaritari
# Processing Record 157|namibe
# Processing Record 158|barrow
# Processing Record 159|shahr-e babak
# Processing Record 160|tilichiki
# Processing Record 161|nurota
# Processing Record 162|vaitape
# Processing Record 163|zheleznodorozhnyy
# Processing Record 164|ippy
# Processing Record 165|gladstone
# Processing Record 166|kafue
# Processing Record 167|sajanan
# Processing Record 168|caravelas
# Processing Record 169|tibu
# Processing Record 170|dikson
# City not found. Skipping...ngukurr
# Processing Record 172|launceston
# Processing Record 173|klaksvik
# Processing Record 174|tibiri
# Processing Record 175|stephenville
# Processing Record 176|isangel
# Processing Record 177|airai
# City not found. Skipping...deh rawud
# Processing Record 179|minna
# Processing Record 180|ulaangom
# Processing Record 181|bintulu
# Processing Record 182|cap malheureux
# Processing Record 183|ostrovnoy
# Processing Record 184|ambilobe
# Processing Record 185|sistranda
# Processing Record 186|conceicao da barra
# Processing Record 187|cimarron hills
# Processing Record 188|rosetown
# Processing Record 189|coihaique
# Processing Record 190|berlevag
# Processing Record 191|bengkulu
# Processing Record 192|tautira
# Processing Record 193|kermanshah
# Processing Record 194|geraldton
# City not found. Skipping...scottsburgh
# Processing Record 196|santa cruz cabralia
# Processing Record 197|college
# Processing Record 198|dunedin
# Processing Record 199|igarka
# Processing Record 200|port lincoln
# Processing Record 201|poum
# Processing Record 202|rovaniemi
# Processing Record 203|cherskiy
# Processing Record 204|mattawa
# Processing Record 205|marsa matruh
# Processing Record 206|ust-nera
# Processing Record 207|tolentino
# Processing Record 208|macae
# Processing Record 209|dong hoi
# Processing Record 210|dullewala
# Processing Record 211|kautokeino
# Processing Record 212|koumac
# Processing Record 213|saint george
# Processing Record 214|lebu
# Processing Record 215|tuatapere
# Processing Record 216|nikolskoye
# Processing Record 217|troy
# Processing Record 218|iqaluit
# Processing Record 219|saint-philippe
# Processing Record 220|nakhon thai
# Processing Record 221|anaconda
# Processing Record 222|karlskrona
# Processing Record 223|vao
# City not found. Skipping...port-de-paix
# Processing Record 225|katsuura
# Processing Record 226|chulumani
# Processing Record 227|paulo afonso
# Processing Record 228|hasaki
# Processing Record 229|mackay
# City not found. Skipping...cazaje
# City not found. Skipping...yialos
# Processing Record 232|lesogorskiy
# Processing Record 233|mehamn
# Processing Record 234|tuy hoa
# Processing Record 235|anloga
# Processing Record 236|san quintin
# City not found. Skipping...sinkat
# Processing Record 238|jardim
# Processing Record 239|mogadishu
# Processing Record 240|merano
# Processing Record 241|goundam
# Processing Record 242|alofi
# Processing Record 243|kinna
# Processing Record 244|jinxiang
# Processing Record 245|borba
# Processing Record 246|priekule
# Processing Record 247|obidos
# Processing Record 248|shepsi
# City not found. Skipping...pilao arcado
# Processing Record 250|tambau
# Processing Record 251|tarancon
# Processing Record 252|maneadero
# Processing Record 253|tabou
# Processing Record 254|calabozo
# Processing Record 255|hit
# Processing Record 256|suhbaatar
# Processing Record 257|lazaro cardenas
# Processing Record 258|bridlington
# Processing Record 259|sao filipe
# Processing Record 260|juneau
# City not found. Skipping...tsihombe
# Processing Record 262|suntar
# Processing Record 263|laguna
# Processing Record 264|hobart
# Processing Record 265|zhaotong
# Processing Record 266|saint-augustin
# Processing Record 267|saskylakh
# Processing Record 268|honningsvag
# Processing Record 269|payakumbuh
# Processing Record 270|marystown
# Processing Record 271|faanui
# Processing Record 272|clyde river
# Processing Record 273|bolu
# Processing Record 274|beloha
# Processing Record 275|yerbogachen
# Processing Record 276|cidreira
# Processing Record 277|vitim
# Processing Record 278|provideniya
# Processing Record 279|alice springs
# Processing Record 280|warrnambool
# Processing Record 281|belyy yar
# Processing Record 282|kilakarai
# Processing Record 283|vostok
# Processing Record 284|middleton
# Processing Record 285|los llanos de aridane
# Processing Record 286|barra patuca
# Processing Record 287|herat
# Processing Record 288|jimani
# Processing Record 289|luba
# Processing Record 290|ancud
# Processing Record 291|soyo
# Processing Record 292|tiksi
# Processing Record 293|kedrovyy
# Processing Record 294|sayville
# City not found. Skipping...sentyabrskiy
# Processing Record 296|beihai
# Processing Record 297|marrakesh
# Processing Record 298|camacha
# Processing Record 299|ruteng
# Processing Record 300|henties bay
# City not found. Skipping...falkoping
# Processing Record 302|utevka
# Processing Record 303|anadyr
# Processing Record 304|hamilton
# Processing Record 305|port blair
# Processing Record 306|north myrtle beach
# Processing Record 307|oriximina
# Processing Record 308|imbituba
# Processing Record 309|jalingo
# Processing Record 310|ternate
# Processing Record 311|aklavik
# Processing Record 312|cedar city
# Processing Record 313|flinders
# Processing Record 314|finnsnes
# Processing Record 315|lungi
# Processing Record 316|khorixas
# Processing Record 317|severo-kurilsk
# Processing Record 318|yeppoon
# Processing Record 319|kuytun
# Processing Record 320|beringovskiy
# Processing Record 321|fonte boa
# Processing Record 322|kavieng
# Processing Record 323|marawi
# Processing Record 324|cayenne
# Processing Record 325|tuktoyaktuk
# Processing Record 326|hortolandia
# Processing Record 327|kalaleh
# Processing Record 328|faya
# Processing Record 329|mandera
# Processing Record 330|murmashi
# Processing Record 331|avera
# City not found. Skipping...agha jari
# Processing Record 333|rio amarillo
# Processing Record 334|pucallpa
# Processing Record 335|campos
# Processing Record 336|verkhoyansk
# Processing Record 337|lorengau
# Processing Record 338|lac du bonnet
# Processing Record 339|kysyl-syr
# Processing Record 340|half moon bay
# Processing Record 341|atambua
# Processing Record 342|kutum
# City not found. Skipping...mocambique
# Processing Record 344|palmer
# Processing Record 345|mozarlandia
# Processing Record 346|jalu
# Processing Record 347|lichinga
# Processing Record 348|georgetown
# Processing Record 349|codrington
# Processing Record 350|bandarbeyla
# Processing Record 351|derzhavinsk
# Processing Record 352|rawson
# Processing Record 353|hirado
# Processing Record 354|sechura
# Processing Record 355|thompson
# Processing Record 356|praia da vitoria
# Processing Record 357|simi
# City not found. Skipping...grand river south east
# Processing Record 359|zhigansk
# Processing Record 360|antofagasta
# Processing Record 361|saldanha
# Processing Record 362|siverek
# Processing Record 363|necochea
# Processing Record 364|grand-santi
# Processing Record 365|san patricio
# Processing Record 366|chiang klang
# Processing Record 367|mokhsogollokh
# Processing Record 368|atar
# Processing Record 369|srednekolymsk
# Processing Record 370|yinchuan
# Processing Record 371|yanam
# Processing Record 372|keetmanshoop
# City not found. Skipping...duz
# Processing Record 374|chebsara
# Processing Record 375|sonthofen
# Processing Record 376|samarai
# Processing Record 377|perbaungan
# Processing Record 378|tayu
# Processing Record 379|okakarara
# Processing Record 380|hede
# Processing Record 381|fairbanks
# Processing Record 382|kawalu
# Processing Record 383|meulaboh
# Processing Record 384|mandalgovi
# Processing Record 385|mecca
# Processing Record 386|kununurra
# Processing Record 387|general pico
# Processing Record 388|carnarvon
# Processing Record 389|urucui
# Processing Record 390|sogne
# Processing Record 391|bilibino
# Processing Record 392|amboasary
# Processing Record 393|epe
# Processing Record 394|portland
# Processing Record 395|koslan
# Processing Record 396|ferme-neuve
# Processing Record 397|soria
# Processing Record 398|san policarpo
# Processing Record 399|ekibastuz
# Processing Record 400|witu
# Processing Record 401|muros
# Processing Record 402|arak
# Processing Record 403|rio gallegos
# Processing Record 404|peniche
# Processing Record 405|ciudad guayana
# Processing Record 406|baykit
# Processing Record 407|borazjan
# Processing Record 408|nagapattinam
# Processing Record 409|cockburn town
# Processing Record 410|banjar
# City not found. Skipping...bolungarvik
# Processing Record 412|challapata
# Processing Record 413|grindavik
# Processing Record 414|glenwood springs
# Processing Record 415|eluru
# Processing Record 416|banepa
# Processing Record 417|aswan
# Processing Record 418|dickinson
# Processing Record 419|calama
# Processing Record 420|zabaykalsk
# City not found. Skipping...tumannyy
# Processing Record 422|bonwapitse
# Processing Record 423|maryville
# Processing Record 424|vitoria da conquista
# Processing Record 425|marquette
# Processing Record 426|spas-demensk
# City not found. Skipping...jahrom
# Processing Record 428|wasilla
# Processing Record 429|ojinaga
# ------------------------------------------------------------------
# KeyboardInterrupt                Traceback (most recent call last)
# <ipython-input-4-778358e592d2> in <module>
#      18     url_weather="http://api.openweathermap.org/data/2.5/weather?"
#      19     query_url=f"{url_weather}appid={weather_api_key}&q={city}"
# ---> 20     weather_response=requests.get(query_url)
#      21     weather_json=weather_response.json()
#      22
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_dic={'City':city_data,
          'Lat':coord_lat,
          'lng':coord_lon,
          'Max Temp':main_max_temp,
          'Humidity':humidity,
          'Cloudiness':cloudiness,
          'Wind Speed':wind_speed,
          'Country':country,
          'Date':dt}
city_data_df=pd.DataFrame(city_dic)
city_data_df

#export the city data into .CSV
city_data_df.to_csv('weather_CSV/weather_data.csv')

#display the data frame.
city_data_df
# Out:
#                      City      Lat       lng  Max Temp  Humidity  Cloudiness  \
# 0               manokwari  -0.8667  134.0833    299.89        77          87
# 1               mahebourg -20.4081   57.7000    303.15        66          40
# 2               hithadhoo  -0.6000   73.0833    302.13        63           4
# 3               busselton -33.6500  115.3333    303.71        55          91
# 4                chipinge -20.1883   32.6236    298.28        57           0
# ..                    ...      ...       ...       ...       ...         ...
# 392  vitoria da conquista -14.8661  -40.8394    290.32        91          29
# 393             marquette  46.5333  -87.6335    280.93        70         100
# 394          spas-demensk  54.4122   34.0226    261.93        95         100
# 395               wasilla  61.5814 -149.4394    273.15        93          90
# 396               ojinaga  29.5667 -104.4167    291.15        36           1
#
#      Wind Speed Country        Date
# 0          3.11      ID  1615364481
# 1          5.66      MU  1615364481
# 2          2.59      MV  1615364482
# 3          1.79      AU  1615364482
# 4          1.32      ZW  1615364483
# ..          ...     ...         ...
# 392        1.50      BR  1615364410
# 393        0.89      US  1615364599
# 394        2.43      RU  1615364599
# 395        1.76      US  1615364600
# 396        2.57      MX  1615364354
#
# [397 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#sortting all the values under humidity 
humidity_df=city_data_df.sort_values('Humidity',ascending=False)
humidity_df
#This step needs to be skiped since there is no values over 100 under humidity.
# Out:
#              City      Lat       lng  Max Temp  Humidity  Cloudiness  \
# 274        ruteng  -8.6136  120.4721    293.87       100         100
# 65    orange cove  36.6244 -119.3137    283.15       100          75
# 266         ancud -41.8697  -73.8203    287.59       100          90
# 190         macae -22.3708  -41.7869    295.15       100          40
# 161         airai  -8.9266  125.4092    291.13       100         100
# ..            ...      ...       ...       ...       ...         ...
# 187  marsa matruh  31.3525   27.2453    295.15        15           0
# 315         kutum  14.2000   24.6667    301.61        12           0
# 134     athmallik  20.7219   84.5348    312.58        11           4
# 85         riyadh  24.6877   46.7219    299.15        11           0
# 158        tibiri  13.5627    7.0485    303.15         9           0
#
#      Wind Speed Country        Date
# 274        0.58      ID  1615364563
# 65         3.60      US  1615364501
# 266        4.12      CL  1615364561
# 190        1.54      BR  1615364539
# 161        0.41      TL  1615364530
# ..          ...     ...         ...
# 187        6.17      EG  1615364538
# 315        3.60      SD  1615364575
# 134        3.10      IN  1615364522
# 85         3.60      SA  1615364217
# 158        6.17      NE  1615364529
#
# [397 rows x 9 columns]

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# !mkdir figure
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker="o", s=10)

plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("figure/plotLatitudeVsTemperaturePlot.png")

plt.show()
# Out:
# A subdirectory or file figure already exists.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
