# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 609

# %%
url_weather="http://api.openweathermap.org/data/2.5/weather?"
url=f"{url_weather}appid={weather_api_key}&q={city}"

response=requests.get(url)
data=response.json()
data
# Out:
# {'coord': {'lon': 98.7792, 'lat': 1.7427},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 303.7,
#   'feels_like': 306.06,
#   'temp_min': 303.7,
#   'temp_max': 303.7,
#   'pressure': 1012,
#   'humidity': 58,
#   'sea_level': 1012,
#   'grnd_level': 1010},
#  'visibility': 10000,
#  'wind': {'speed': 2.84, 'deg': 240},
#  'clouds': {'all': 91},
#  'dt': 1615437217,
#  'sys': {'country': 'ID', 'sunrise': 1615419131, 'sunset': 1615462675},
#  'timezone': 25200,
#  'id': 1213855,
#  'name': 'Sibolga',
#  'cod': 200}

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#checking for the URL query

count_city=1

city_data=[]
coord_lat=[]
coord_lon=[]
main_max_temp=[]
humidity=[]
cloudiness=[]
wind_speed=[]
country=[]
dt=[]

for city in cities:
    
    #retrive url and request the json file
    url_weather="http://api.openweathermap.org/data/2.5/weather?"
    query_url=f"{url_weather}appid={weather_api_key}&q={city}"
    weather_response=requests.get(query_url)
    weather_json=weather_response.json()
    
    #run loop on all cities with data needed.
    try:
        
        coord_lat.append(weather_json['coord']['lat'])
        coord_lon.append(weather_json['coord']['lon'])
        main_max_temp.append(weather_json['main']['temp_max'])
        humidity.append(weather_json['main']['humidity'])
        cloudiness.append(weather_json['clouds']['all'])
        wind_speed.append(weather_json['wind']['speed'])
        country.append(weather_json['sys']['country'])
        dt.append(weather_json['dt'])
        city_data.append(city)
        print(f"Processing Record {count_city}|{city}")
    except:
         print(f'City not found. Skipping...{city}')
            
    count_city+=1
# Out:
# Processing Record 1|qaqortoq
# Processing Record 2|barrow
# Processing Record 3|geraldton
# Processing Record 4|rikitea
# Processing Record 5|itaueira
# Processing Record 6|busselton
# Processing Record 7|souillac
# Processing Record 8|bealanana
# City not found. Skipping...taolanaro
# Processing Record 10|upernavik
# Processing Record 11|cayenne
# Processing Record 12|padang
# Processing Record 13|pitiquito
# Processing Record 14|arraial do cabo
# Processing Record 15|rio bueno
# Processing Record 16|punta arenas
# Processing Record 17|puebloviejo
# Processing Record 18|kruisfontein
# City not found. Skipping...guajara-mirim
# Processing Record 20|srivardhan
# Processing Record 21|port alfred
# Processing Record 22|acarau
# Processing Record 23|sao raimundo nonato
# Processing Record 24|fenoarivo
# Processing Record 25|zyryanka
# Processing Record 26|adre
# Processing Record 27|bambous virieux
# Processing Record 28|coihaique
# Processing Record 29|henties bay
# Processing Record 30|hobart
# Processing Record 31|konevo
# Processing Record 32|batagay
# Processing Record 33|chokurdakh
# Processing Record 34|vostok
# Processing Record 35|yellowknife
# Processing Record 36|tiksi
# Processing Record 37|ukiah
# Processing Record 38|saint george
# Processing Record 39|bathsheba
# Processing Record 40|juli
# Processing Record 41|nanortalik
# Processing Record 42|rimouski
# Processing Record 43|bluff
# City not found. Skipping...attawapiskat
# Processing Record 45|ponta delgada
# Processing Record 46|cape town
# Processing Record 47|mataura
# Processing Record 48|kapaa
# City not found. Skipping...kawana waters
# Processing Record 50|iqaluit
# Processing Record 51|bestobe
# Processing Record 52|vila velha
# Processing Record 53|poum
# Processing Record 54|nosy varika
# Processing Record 55|dikson
# Processing Record 56|leningradskiy
# Processing Record 57|port lincoln
# Processing Record 58|lufilufi
# Processing Record 59|saskylakh
# Processing Record 60|ushuaia
# Processing Record 61|sitka
# Processing Record 62|tasiilaq
# Processing Record 63|turtas
# Processing Record 64|vaini
# Processing Record 65|kaitangata
# City not found. Skipping...vaitupu
# Processing Record 67|puerto ayora
# Processing Record 68|stornoway
# Processing Record 69|albany
# Processing Record 70|yeppoon
# City not found. Skipping...daosa
# Processing Record 72|kedgwick
# Processing Record 73|east london
# Processing Record 74|san policarpo
# Processing Record 75|kaeo
# Processing Record 76|inhambane
# Processing Record 77|torbay
# Processing Record 78|thompson
# Processing Record 79|oranjemund
# Processing Record 80|avarua
# Processing Record 81|nesna
# Processing Record 82|dingle
# Processing Record 83|jamestown
# Processing Record 84|yerbogachen
# Processing Record 85|longyearbyen
# Processing Record 86|svetlyy
# Processing Record 87|citta di castello
# Processing Record 88|russell
# Processing Record 89|atuona
# Processing Record 90|omis
# Processing Record 91|robertsport
# Processing Record 92|cockburn town
# Processing Record 93|airai
# Processing Record 94|viedma
# Processing Record 95|ribeira grande
# Processing Record 96|cabo san lucas
# Processing Record 97|georgetown
# Processing Record 98|cherskiy
# City not found. Skipping...higuey
# Processing Record 100|sorland
# Processing Record 101|srednekolymsk
# Processing Record 102|ponta do sol
# Processing Record 103|qaanaaq
# Processing Record 104|upata
# Processing Record 105|hermanus
# Processing Record 106|magadan
# Processing Record 107|rio linda
# Processing Record 108|barranca
# Processing Record 109|burnie
# City not found. Skipping...amderma
# Processing Record 111|tuktoyaktuk
# Processing Record 112|sao joao da barra
# City not found. Skipping...belushya guba
# Processing Record 114|atocha
# Processing Record 115|roald
# Processing Record 116|mae sai
# Processing Record 117|jarva-jaani
# Processing Record 118|lompoc
# Processing Record 119|okha
# Processing Record 120|talaya
# Processing Record 121|kushima
# Processing Record 122|alofi
# Processing Record 123|ilulissat
# Processing Record 124|thunder bay
# Processing Record 125|aykhal
# Processing Record 126|la guaira
# Processing Record 127|satipo
# Processing Record 128|hobyo
# Processing Record 129|valdivia
# Processing Record 130|hithadhoo
# Processing Record 131|new norfolk
# Processing Record 132|columbia
# Processing Record 133|norman wells
# Processing Record 134|tiruchchendur
# Processing Record 135|bethel
# Processing Record 136|ostrovnoy
# City not found. Skipping...tsentralnyy
# Processing Record 138|hasaki
# Processing Record 139|bismarck
# Processing Record 140|capinopolis
# Processing Record 141|te anau
# Processing Record 142|bayan
# Processing Record 143|parfenyevo
# Processing Record 144|georgiyevka
# Processing Record 145|honningsvag
# Processing Record 146|mamallapuram
# Processing Record 147|kahului
# Processing Record 148|mafeteng
# City not found. Skipping...tumannyy
# Processing Record 150|provideniya
# Processing Record 151|bredasdorp
# Processing Record 152|hilo
# Processing Record 153|khandyga
# Processing Record 154|vardo
# Processing Record 155|bay roberts
# City not found. Skipping...barentsburg
# Processing Record 157|isangel
# Processing Record 158|taybad
# Processing Record 159|tautira
# Processing Record 160|nieves
# Processing Record 161|klaksvik
# Processing Record 162|ahipara
# Processing Record 163|pemba
# Processing Record 164|sterling
# Processing Record 165|duku
# Processing Record 166|alta floresta
# Processing Record 167|sur
# Processing Record 168|sydney
# Processing Record 169|pevek
# Processing Record 170|tigil
# City not found. Skipping...saleilua
# Processing Record 172|karlstad
# Processing Record 173|kyabram
# Processing Record 174|lakatoro
# City not found. Skipping...mentok
# Processing Record 176|trencin
# Processing Record 177|tongchuan
# Processing Record 178|tuatapere
# Processing Record 179|fort nelson
# Processing Record 180|muli
# City not found. Skipping...tsihombe
# Processing Record 182|mar del plata
# Processing Record 183|volchikha
# Processing Record 184|flinders
# Processing Record 185|tacoronte
# City not found. Skipping...saleaula
# Processing Record 187|praya
# Processing Record 188|chuy
# Processing Record 189|sumenep
# Processing Record 190|pedernales
# Processing Record 191|norsup
# Processing Record 192|ambovombe
# Processing Record 193|butaritari
# Processing Record 194|comodoro rivadavia
# Processing Record 195|ust-nera
# Processing Record 196|victoria
# Processing Record 197|nemuro
# Processing Record 198|bengkulu
# Processing Record 199|ola
# Processing Record 200|codrington
# Processing Record 201|kailua
# Processing Record 202|banda aceh
# Processing Record 203|laguna
# Processing Record 204|castro
# Processing Record 205|salalah
# Processing Record 206|praia da vitoria
# Processing Record 207|yulara
# Processing Record 208|cacu
# Processing Record 209|grindavik
# Processing Record 210|santiago del estero
# Processing Record 211|shirokiy
# Processing Record 212|jinchang
# City not found. Skipping...umzimvubu
# Processing Record 214|chumikan
# Processing Record 215|bandarbeyla
# Processing Record 216|aksarka
# Processing Record 217|mayor pablo lagerenza
# Processing Record 218|jibuti
# Processing Record 219|mozarlandia
# Processing Record 220|lavrentiya
# Processing Record 221|mahajanga
# City not found. Skipping...kamenskoye
# Processing Record 223|lasa
# Processing Record 224|yuksekova
# Processing Record 225|mahebourg
# Processing Record 226|makat
# Processing Record 227|kabare
# Processing Record 228|la union
# Processing Record 229|mokhsogollokh
# Processing Record 230|komsomolskiy
# Processing Record 231|lorengau
# Processing Record 232|diu
# Processing Record 233|semnan
# Processing Record 234|esperance
# Processing Record 235|ternate
# Processing Record 236|san patricio
# Processing Record 237|phan thiet
# Processing Record 238|angoche
# Processing Record 239|coquimbo
# Processing Record 240|punta alta
# Processing Record 241|riyadh
# City not found. Skipping...sentyabrskiy
# Processing Record 243|lulea
# Processing Record 244|hami
# Processing Record 245|mweka
# Processing Record 246|faya
# Processing Record 247|wakkanai
# Processing Record 248|mogadishu
# Processing Record 249|ayan
# Processing Record 250|svetlogorsk
# Processing Record 251|husavik
# City not found. Skipping...illoqqortoormiut
# Processing Record 253|palu
# Processing Record 254|lykhivka
# Processing Record 255|jiaozuo
# Processing Record 256|zyryanovsk
# Processing Record 257|talcahuano
# Processing Record 258|petersburg
# Processing Record 259|erenhot
# Processing Record 260|guerrero negro
# Processing Record 261|talnakh
# Processing Record 262|acapulco
# Processing Record 263|santa lucia
# Processing Record 264|latung
# Processing Record 265|conil
# Processing Record 266|chapais
# Processing Record 267|mosquera
# Processing Record 268|buchanan
# Processing Record 269|traverse city
# City not found. Skipping...burica
# Processing Record 271|ancud
# Processing Record 272|vao
# Processing Record 273|puro
# Processing Record 274|el dorado
# Processing Record 275|zavetnoye
# Processing Record 276|dayong
# Processing Record 277|narsaq
# Processing Record 278|clyde river
# Processing Record 279|tshikapa
# Processing Record 280|sladkovo
# Processing Record 281|elko
# Processing Record 282|nizhnevartovsk
# Processing Record 283|labuhan
# City not found. Skipping...mys shmidta
# Processing Record 285|lujiang
# City not found. Skipping...samusu
# City not found. Skipping...mudyuga
# Processing Record 288|chikhli
# Processing Record 289|erzurum
# City not found. Skipping...grand river south east
# Processing Record 291|sinnamary
# Processing Record 292|nikolskoye
# Processing Record 293|kaka
# Processing Record 294|roebourne
# Processing Record 295|zelenogorskiy
# City not found. Skipping...warqla
# Processing Record 297|shaoyang
# Processing Record 298|umm lajj
# Processing Record 299|mango
# Processing Record 300|vila franca do campo
# Processing Record 301|taltal
# Processing Record 302|yar-sale
# Processing Record 303|takoradi
# Processing Record 304|lebu
# Processing Record 305|huari
# Processing Record 306|itarema
# City not found. Skipping...kuche
# Processing Record 308|nouakchott
# Processing Record 309|sagua la grande
# Processing Record 310|fallon
# Processing Record 311|killam
# Processing Record 312|port hardy
# Processing Record 313|carnarvon
# Processing Record 314|maraba
# Processing Record 315|chau doc
# Processing Record 316|maraa
# City not found. Skipping...marcona
# Processing Record 318|say
# City not found. Skipping...talawdi
# Processing Record 320|whitehorse
# Processing Record 321|barrington
# City not found. Skipping...skalistyy
# City not found. Skipping...sinkat
# Processing Record 324|vanimo
# Processing Record 325|hamilton
# Processing Record 326|bubaque
# Processing Record 327|north bend
# Processing Record 328|fairbanks
# Processing Record 329|necochea
# Processing Record 330|parrita
# Processing Record 331|port elizabeth
# Processing Record 332|moron
# Processing Record 333|hovd
# Processing Record 334|clearwater
# Processing Record 335|cidreira
# Processing Record 336|sumbe
# Processing Record 337|ulaanbaatar
# Processing Record 338|ugoofaaru
# Processing Record 339|bemidji
# Processing Record 340|vestmannaeyjar
# Processing Record 341|cabedelo
# Processing Record 342|hofgeismar
# Processing Record 343|guanica
# Processing Record 344|uaua
# Processing Record 345|caravelas
# Processing Record 346|nome
# City not found. Skipping...hihifo
# Processing Record 348|bosaso
# Processing Record 349|plettenberg bay
# Processing Record 350|saint-philippe
# Processing Record 351|moose jaw
# Processing Record 352|bakel
# Processing Record 353|neuquen
# Processing Record 354|kavaratti
# Processing Record 355|jamame
# City not found. Skipping...jinchengjiang
# Processing Record 357|baft
# Processing Record 358|nuuk
# Processing Record 359|emba
# Processing Record 360|lubango
# Processing Record 361|ozubulu
# Processing Record 362|sao jose da coroa grande
# Processing Record 363|paamiut
# Processing Record 364|diego de almagro
# Processing Record 365|kieta
# City not found. Skipping...palabuhanratu
# Processing Record 367|tilichiki
# Processing Record 368|verkhnyaya inta
# Processing Record 369|khani
# City not found. Skipping...manzil tamim
# Processing Record 371|winslow
# Processing Record 372|baruun-urt
# Processing Record 373|murray bridge
# Processing Record 374|ambon
# Processing Record 375|khash
# Processing Record 376|kloulklubed
# Processing Record 377|montepuez
# Processing Record 378|todos santos
# Processing Record 379|blackfoot
# Processing Record 380|la ronge
# Processing Record 381|grafton
# Processing Record 382|macedo de cavaleiros
# Processing Record 383|czersk
# Processing Record 384|namibe
# City not found. Skipping...cape elizabeth
# City not found. Skipping...ambodifototra
# Processing Record 387|karratha
# Processing Record 388|fukue
# Processing Record 389|constitucion
# Processing Record 390|mezapa
# Processing Record 391|vejle
# Processing Record 392|ust-tsilma
# Processing Record 393|yuma
# Processing Record 394|orchard homes
# Processing Record 395|kavieng
# Processing Record 396|lagoa
# Processing Record 397|tura
# Processing Record 398|shaunavon
# Processing Record 399|songea
# Processing Record 400|guaruja
# Processing Record 401|marovoay
# Processing Record 402|denpasar
# Processing Record 403|mackay
# Processing Record 404|matara
# Processing Record 405|khatanga
# Processing Record 406|kysyl-syr
# Processing Record 407|dunedin
# Processing Record 408|kamaishi
# Processing Record 409|gat
# Processing Record 410|pisco
# Processing Record 411|muros
# Processing Record 412|tocopilla
# Processing Record 413|tyup
# Processing Record 414|fortuna
# Processing Record 415|kawasaki
# Processing Record 416|broome
# Processing Record 417|salur
# Processing Record 418|fort-shevchenko
# Processing Record 419|anqing
# Processing Record 420|sao filipe
# Processing Record 421|san quintin
# Processing Record 422|manakara
# Processing Record 423|miguel hidalgo
# Processing Record 424|mangrol
# Processing Record 425|katsuura
# Processing Record 426|college
# Processing Record 427|eureka
# Processing Record 428|dryden
# Processing Record 429|bindura
# Processing Record 430|abu samrah
# Processing Record 431|xuddur
# Processing Record 432|west bay
# Processing Record 433|asau
# Processing Record 434|shimoda
# Processing Record 435|francistown
# Processing Record 436|catuday
# Processing Record 437|ust-maya
# Processing Record 438|manoel urbano
# Processing Record 439|izvoarele sucevei
# Processing Record 440|kumluca
# Processing Record 441|luderitz
# Processing Record 442|bilibino
# Processing Record 443|jumla
# Processing Record 444|umea
# Processing Record 445|amapa
# Processing Record 446|iskateley
# Processing Record 447|acajutla
# Processing Record 448|mpika
# Processing Record 449|portland
# Processing Record 450|margate
# Processing Record 451|saldanha
# Processing Record 452|san rafael
# Processing Record 453|okhotsk
# Processing Record 454|chunoyar
# Processing Record 455|lewiston
# Processing Record 456|ekhabi
# Processing Record 457|salinas
# City not found. Skipping...babanusah
# Processing Record 459|lyantonde
# Processing Record 460|dzerzhinsk
# Processing Record 461|enumclaw
# Processing Record 462|touros
# Processing Record 463|zharkent
# Processing Record 464|ahuimanu
# Processing Record 465|usta muhammad
# Processing Record 466|saint-francois
# Processing Record 467|beidao
# Processing Record 468|dothan
# City not found. Skipping...nizhneyansk
# Processing Record 470|edson
# Processing Record 471|luka nad jihlavou
# City not found. Skipping...mendahara
# Processing Record 473|port hawkesbury
# Processing Record 474|kodiak
# City not found. Skipping...tir pol
# Processing Record 476|akyab
# Processing Record 477|darnah
# Processing Record 478|tombouctou
# Processing Record 479|samarai
# Processing Record 480|surin
# Processing Record 481|madridejos
# Processing Record 482|bonnyville
# Processing Record 483|hofn
# Processing Record 484|barcelos
# Processing Record 485|kindu
# Processing Record 486|maicanesti
# Processing Record 487|usinsk
# City not found. Skipping...matsanga
# Processing Record 489|sol-iletsk
# Processing Record 490|leh
# Processing Record 491|wajima
# Processing Record 492|tabou
# Processing Record 493|raudeberg
# Processing Record 494|lazarev
# Processing Record 495|pemangkat
# City not found. Skipping...gilazi
# Processing Record 497|rockland
# Processing Record 498|maningrida
# Processing Record 499|haines junction
# Processing Record 500|okahandja
# Processing Record 501|beian
# City not found. Skipping...ust-bolsheretsk
# Processing Record 503|buy
# Processing Record 504|rabo de peixe
# Processing Record 505|dulce grande
# Processing Record 506|nizwa
# Processing Record 507|payo
# Processing Record 508|camacha
# Processing Record 509|korla
# Processing Record 510|rocha
# Processing Record 511|gilbues
# Processing Record 512|portmarnock
# Processing Record 513|katherine
# Processing Record 514|osorno
# Processing Record 515|curillo
# Processing Record 516|dunn
# Processing Record 517|abnub
# Processing Record 518|tiznit
# Processing Record 519|quatre cocos
# Processing Record 520|nyalikungu
# Processing Record 521|naze
# Processing Record 522|lazaro cardenas
# Processing Record 523|inuvik
# Processing Record 524|atikokan
# Processing Record 525|oyama
# Processing Record 526|mandalgovi
# Processing Record 527|boa vista
# Processing Record 528|los llanos de aridane
# Processing Record 529|southbridge
# Processing Record 530|qinhuangdao
# Processing Record 531|camabatela
# Processing Record 532|temir
# Processing Record 533|touba
# Processing Record 534|bundaberg
# City not found. Skipping...bur gabo
# City not found. Skipping...kadykchan
# Processing Record 537|taoudenni
# Processing Record 538|sangar
# Processing Record 539|bonavista
# Processing Record 540|sabya
# Processing Record 541|kalmar
# Processing Record 542|kudahuvadhoo
# Processing Record 543|kenai
# Processing Record 544|belaya gora
# Processing Record 545|paka
# Processing Record 546|atar
# City not found. Skipping...rawannawi
# Processing Record 548|anahuac
# Processing Record 549|zhenlai
# City not found. Skipping...eskasem
# Processing Record 551|kedrovyy
# Processing Record 552|colac
# Processing Record 553|fort smith
# Processing Record 554|maun
# Processing Record 555|palmer
# Processing Record 556|schwanewede
# Processing Record 557|constantine
# Processing Record 558|sabha
# Processing Record 559|tromso
# City not found. Skipping...bandar-e torkaman
# Processing Record 561|rosario
# Processing Record 562|zheleznodorozhnyy
# Processing Record 563|saveh
# Processing Record 564|socorro
# Processing Record 565|marsh harbour
# Processing Record 566|sabang
# Processing Record 567|indianola
# Processing Record 568|mount isa
# Processing Record 569|chimbote
# Processing Record 570|lake cowichan
# Processing Record 571|sept-iles
# Processing Record 572|edd
# Processing Record 573|ratnagiri
# Processing Record 574|ucluelet
# Processing Record 575|hay river
# City not found. Skipping...grand centre
# Processing Record 577|terrace bay
# Processing Record 578|birao
# Processing Record 579|morros
# Processing Record 580|varkkallai
# Processing Record 581|faanui
# Processing Record 582|nizhniy kuranakh
# Processing Record 583|marabba
# Processing Record 584|lafayette
# Processing Record 585|tevaitoa
# Processing Record 586|novobelokatay
# Processing Record 587|la primavera
# Processing Record 588|westport
# Processing Record 589|kochubey
# Processing Record 590|ambilobe
# Processing Record 591|farafangana
# Processing Record 592|guacimo
# Processing Record 593|mbigou
# Processing Record 594|aklavik
# Processing Record 595|saint-pierre
# Processing Record 596|karasjok
# Processing Record 597|petukhovo
# Processing Record 598|dharchula
# Processing Record 599|yuza
# Processing Record 600|sakaiminato
# Processing Record 601|strezhevoy
# Processing Record 602|aswan
# City not found. Skipping...tawkar
# Processing Record 604|nishihara
# Processing Record 605|huron
# Processing Record 606|puerto lempira
# Processing Record 607|goroka
# City not found. Skipping...bargal
# Processing Record 609|sibolga

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#!mkdir weather_CSV

city_dic={'City':city_data,
          'Lat':coord_lat,
          'lng':coord_lon,
          'Max Temp':main_max_temp,
          'Humidity':humidity,
          'Cloudiness':cloudiness,
          'Wind Speed':wind_speed,
          'Country':country,
          'Date':dt}
city_data_df=pd.DataFrame(city_dic)
city_data_df

#export the city data into .CSV
city_data_df.to_csv('weather_CSV/weather_data.csv')

#display the data frame.
city_data_df
# Out:
#                City      Lat       lng  Max Temp  Humidity  Cloudiness  \
# 0          qaqortoq  60.7167  -46.0333    268.15        80          75
# 1            barrow  71.2906 -156.7887    250.15        70          20
# 2         geraldton -28.7667  114.6000    303.15        54          31
# 3           rikitea -23.1203 -134.9692    299.40        75          47
# 4          itaueira  -7.6033  -43.0256    295.47        87          34
# ..              ...      ...       ...       ...       ...         ...
# 552       nishihara  26.1842  127.7558    298.15        46          20
# 553           huron  41.1501  -82.5499    289.82        41         100
# 554  puerto lempira  15.2667  -83.7667    297.14        87           0
# 555          goroka  -6.0834  145.3873    294.97        78          93
# 556         sibolga   1.7427   98.7792    303.70        58          91
#
#      Wind Speed Country        Date
# 0          2.06      GL  1615437218
# 1          5.66      US  1615437219
# 2          6.69      AU  1615437219
# 3          8.58      PF  1615437219
# 4          1.14      BR  1615437219
# ..          ...     ...         ...
# 552        6.17      JP  1615437389
# 553        3.13      US  1615437389
# 554        3.42      HN  1615437389
# 555        1.58      PG  1615437390
# 556        2.84      ID  1615437217
#
# [557 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#sortting all the values under humidity 
humidity_df=city_data_df.sort_values('Humidity',ascending=False)
humidity_df
#This step needs to be skiped since there is no values over 100 under humidity.
# Out:
#                  City      Lat       lng  Max Temp  Humidity  Cloudiness  \
# 86              airai  -8.9266  125.4092    293.87       100          78
# 249             ancud -41.8697  -73.8203    282.59       100          20
# 189  praia da vitoria  38.7333  -27.0667    287.04       100          90
# 244             conil  44.9673    3.7177    274.59       100         100
# 236        talcahuano -36.7167  -73.1167    288.15       100          90
# ..                ...      ...       ...       ...       ...         ...
# 263           chikhli  20.3500   76.2500    306.57        14          22
# 289               say  13.1007    2.3689    301.15        14           0
# 426     usta muhammad  28.1794   68.0445    302.78        14           0
# 461             nizwa  22.9333   57.5333    302.61        14           0
# 514           socorro  31.6546 -106.3033    291.15         7          20
#
#      Wind Speed Country        Date
# 86         0.29      TL  1615437244
# 249        2.06      CL  1615437292
# 189        4.88      PT  1615437274
# 244        2.48      FR  1615437291
# 236        2.57      CL  1615437288
# ..          ...     ...         ...
# 263        6.91      IN  1615437262
# 289        3.60      NE  1615437306
# 426        2.63      PK  1615437348
# 461        1.14      OM  1615437361
# 514        7.20      US  1615437206
#
# [557 rows x 9 columns]

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# def imganalisys(columnX,columnY):
#     plt.scatter(city_data_df[""], city_data_df["columnY"], marker="o", s=15)
#     plt.xlabel("Latitude")
#     plt.grid(True)
#     return

# %%
#!mkdir figure

#imganalisys('Lat','Max Temp')

plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, s=30)
plt.xlabel("Latitude")
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")

plt.grid(True)
plt.savefig("figure/plotLatitudeVsTemperaturePlot.png")

plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#imganalisys('Lat','Humidity')
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolor="black", linewidths=1, marker="o", 
            alpha=0.9, s=30)
plt.xlabel("Latitude")
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity(%)")

plt.grid(True)
plt.savefig("figure/plotLatitudeVsHumidityPlot.png")

plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolor="black", linewidths=1, marker="o", 
            alpha=0.9, s=30)

plt.title(" Latitude vs. Cloudiness Plot")
plt.ylabel("Cloudiness(%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("figure/plotLatitudeVsCloudinessPlot.png")

plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolor="black", linewidths=1, marker="o", 
            alpha=0.9, s=30)

plt.title(f" Latitude vs. Wind Speed Plot")
plt.ylabel("wind speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("figure/plotLatitudeVsWindSpeedPlot.png")

plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
