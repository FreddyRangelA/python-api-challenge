# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
import os

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 597

# %%
# url_weather="http://api.openweathermap.org/data/2.5/weather?"
# url=f"{url_weather}appid={weather_api_key}&q={city}&units=imperial"

# response=requests.get(url)
# data=response.json()
# data

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#checking for the URL query

count_city=1
set_city=1

city_data=[]
coord_lat=[]
coord_lon=[]
main_max_temp=[]
humidity=[]
cloudiness=[]
wind_speed=[]
country=[]
dt=[]


print(os.linesep.join(['Beginning Data Retrieval', '-----------------------------']))

for city in cities:
    
    #retrive url and request the json file
    url_weather="http://api.openweathermap.org/data/2.5/weather?"
    query_url=f"{url_weather}appid={weather_api_key}&q={city}&units=imperial"
    weather_response=requests.get(query_url)
    weather_json=weather_response.json()
    
    #run loop on all cities with data needed.
    try:
        
        coord_lat.append(weather_json['coord']['lat'])
        coord_lon.append(weather_json['coord']['lon'])
        main_max_temp.append(weather_json['main']['temp_max'])
        humidity.append(weather_json['main']['humidity'])
        cloudiness.append(weather_json['clouds']['all'])
        wind_speed.append(weather_json['wind']['speed'])
        country.append(weather_json['sys']['country'])
        dt.append(weather_json['dt'])
        city_data.append(city)
        print(f"Processing Record {count_city} of set {set_city}|{city}")
    except:
         print(f'City not found. Skipping...{city}')
            
    count_city+=1
    if count_city== 51:
        count_city=0
        set_city+=1
        

print(os.linesep.join([' ----------------------------- ','Data Retrieval Complete', '-----------------------------']))
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of set 1|hermanus
# Processing Record 2 of set 1|cape town
# Processing Record 3 of set 1|saint-philippe
# Processing Record 4 of set 1|bukachacha
# Processing Record 5 of set 1|thompson
# Processing Record 6 of set 1|mataura
# Processing Record 7 of set 1|tabory
# Processing Record 8 of set 1|victoria
# Processing Record 9 of set 1|mount isa
# Processing Record 10 of set 1|talcahuano
# Processing Record 11 of set 1|albany
# Processing Record 12 of set 1|standerton
# Processing Record 13 of set 1|puerto ayora
# Processing Record 14 of set 1|tuatapere
# Processing Record 15 of set 1|umm lajj
# Processing Record 16 of set 1|castro
# Processing Record 17 of set 1|ossora
# Processing Record 18 of set 1|saldanha
# Processing Record 19 of set 1|faya
# Processing Record 20 of set 1|mar del plata
# Processing Record 21 of set 1|naples
# Processing Record 22 of set 1|hami
# Processing Record 23 of set 1|flinders
# Processing Record 24 of set 1|ahipara
# Processing Record 25 of set 1|sitka
# Processing Record 26 of set 1|avarua
# Processing Record 27 of set 1|hobart
# Processing Record 28 of set 1|woodward
# Processing Record 29 of set 1|kapaa
# Processing Record 30 of set 1|namibe
# Processing Record 31 of set 1|provideniya
# Processing Record 32 of set 1|carnarvon
# Processing Record 33 of set 1|kruisfontein
# Processing Record 34 of set 1|torbay
# Processing Record 35 of set 1|lima
# Processing Record 36 of set 1|port alfred
# Processing Record 37 of set 1|georgetown
# Processing Record 38 of set 1|vao
# Processing Record 39 of set 1|banda aceh
# Processing Record 40 of set 1|adrar
# Processing Record 41 of set 1|tiksi
# Processing Record 42 of set 1|cherskiy
# Processing Record 43 of set 1|salalah
# Processing Record 44 of set 1|upernavik
# Processing Record 45 of set 1|hithadhoo
# Processing Record 46 of set 1|rikitea
# Processing Record 47 of set 1|talaya
# Processing Record 48 of set 1|bluff
# Processing Record 49 of set 1|arraial do cabo
# Processing Record 50 of set 1|buchanan
# Processing Record 0 of set 2|opuwo
# Processing Record 1 of set 2|seoul
# Processing Record 2 of set 2|barrow
# Processing Record 3 of set 2|yulara
# Processing Record 4 of set 2|khatanga
# City not found. Skipping...taolanaro
# Processing Record 6 of set 2|port lincoln
# Processing Record 7 of set 2|sao filipe
# Processing Record 8 of set 2|spokane
# Processing Record 9 of set 2|chuy
# Processing Record 10 of set 2|pangnirtung
# City not found. Skipping...rolim de moura
# Processing Record 12 of set 2|punta arenas
# Processing Record 13 of set 2|brae
# Processing Record 14 of set 2|verkhnyaya toyma
# Processing Record 15 of set 2|xuddur
# Processing Record 16 of set 2|busselton
# Processing Record 17 of set 2|vaini
# Processing Record 18 of set 2|punta alta
# Processing Record 19 of set 2|santa cruz de tenerife
# Processing Record 20 of set 2|severo-kurilsk
# Processing Record 21 of set 2|ushuaia
# Processing Record 22 of set 2|kudahuvadhoo
# Processing Record 23 of set 2|nanortalik
# Processing Record 24 of set 2|caranavi
# Processing Record 25 of set 2|moose factory
# Processing Record 26 of set 2|lianyuan
# Processing Record 27 of set 2|mustafakemalpasa
# Processing Record 28 of set 2|port elizabeth
# Processing Record 29 of set 2|letka
# Processing Record 30 of set 2|matagami
# Processing Record 31 of set 2|riviere-au-renard
# Processing Record 32 of set 2|palmas de monte alto
# Processing Record 33 of set 2|bredasdorp
# Processing Record 34 of set 2|ancud
# Processing Record 35 of set 2|anloga
# Processing Record 36 of set 2|eldorado
# Processing Record 37 of set 2|middle island
# Processing Record 38 of set 2|ribeirao branco
# Processing Record 39 of set 2|lebu
# Processing Record 40 of set 2|tuktoyaktuk
# City not found. Skipping...tabialan
# Processing Record 42 of set 2|port keats
# Processing Record 43 of set 2|okato
# Processing Record 44 of set 2|katsuura
# Processing Record 45 of set 2|mongu
# Processing Record 46 of set 2|atuona
# Processing Record 47 of set 2|tasiilaq
# Processing Record 48 of set 2|butaritari
# Processing Record 49 of set 2|praia da vitoria
# Processing Record 50 of set 2|kutum
# Processing Record 0 of set 3|dikson
# Processing Record 1 of set 3|brownwood
# Processing Record 2 of set 3|cabo san lucas
# Processing Record 3 of set 3|qaanaaq
# Processing Record 4 of set 3|ilulissat
# Processing Record 5 of set 3|nikolskoye
# Processing Record 6 of set 3|goderich
# Processing Record 7 of set 3|pozo colorado
# City not found. Skipping...grand centre
# Processing Record 9 of set 3|isangel
# Processing Record 10 of set 3|nouadhibou
# Processing Record 11 of set 3|faanui
# Processing Record 12 of set 3|ponta delgada
# Processing Record 13 of set 3|tunduma
# Processing Record 14 of set 3|crato
# Processing Record 15 of set 3|chokurdakh
# Processing Record 16 of set 3|klaksvik
# City not found. Skipping...sentyabrskiy
# City not found. Skipping...vaitupu
# Processing Record 19 of set 3|lagoa
# City not found. Skipping...shchelyayur
# Processing Record 21 of set 3|kenora
# Processing Record 22 of set 3|linxia
# Processing Record 23 of set 3|jamestown
# Processing Record 24 of set 3|geraldton
# Processing Record 25 of set 3|port hardy
# Processing Record 26 of set 3|bac lieu
# Processing Record 27 of set 3|savannakhet
# Processing Record 28 of set 3|alofi
# Processing Record 29 of set 3|cehegin
# Processing Record 30 of set 3|hasaki
# Processing Record 31 of set 3|arcata
# Processing Record 32 of set 3|ribeira grande
# Processing Record 33 of set 3|pisco
# Processing Record 34 of set 3|tarragona
# City not found. Skipping...belushya guba
# Processing Record 36 of set 3|menzelinsk
# Processing Record 37 of set 3|itoman
# Processing Record 38 of set 3|alyangula
# Processing Record 39 of set 3|silver city
# Processing Record 40 of set 3|palana
# Processing Record 41 of set 3|diego de almagro
# Processing Record 42 of set 3|maumere
# Processing Record 43 of set 3|goba
# Processing Record 44 of set 3|constitucion
# Processing Record 45 of set 3|honiara
# Processing Record 46 of set 3|lavrentiya
# Processing Record 47 of set 3|alcaniz
# Processing Record 48 of set 3|hamilton
# Processing Record 49 of set 3|hilo
# Processing Record 50 of set 3|lianzhou
# Processing Record 0 of set 4|saskylakh
# Processing Record 1 of set 4|samarai
# Processing Record 2 of set 4|colquechaca
# Processing Record 3 of set 4|norman wells
# Processing Record 4 of set 4|aksarka
# Processing Record 5 of set 4|oranjestad
# Processing Record 6 of set 4|yazman
# Processing Record 7 of set 4|sawtell
# Processing Record 8 of set 4|fortuna
# City not found. Skipping...saryshagan
# Processing Record 10 of set 4|noumea
# City not found. Skipping...grand river south east
# Processing Record 12 of set 4|yellowknife
# Processing Record 13 of set 4|lata
# Processing Record 14 of set 4|dingle
# Processing Record 15 of set 4|ardakan
# Processing Record 16 of set 4|gizo
# Processing Record 17 of set 4|los llanos de aridane
# Processing Record 18 of set 4|lantawan
# Processing Record 19 of set 4|kaitangata
# Processing Record 20 of set 4|kahului
# Processing Record 21 of set 4|grand gaube
# Processing Record 22 of set 4|mildura
# City not found. Skipping...malwan
# Processing Record 24 of set 4|shache
# Processing Record 25 of set 4|bonthe
# City not found. Skipping...umzimvubu
# Processing Record 27 of set 4|bykovo
# Processing Record 28 of set 4|nuuk
# Processing Record 29 of set 4|vinh
# Processing Record 30 of set 4|east london
# City not found. Skipping...palabuhanratu
# Processing Record 32 of set 4|santa rosa
# Processing Record 33 of set 4|tautira
# Processing Record 34 of set 4|wagga wagga
# Processing Record 35 of set 4|zonguldak
# Processing Record 36 of set 4|surt
# Processing Record 37 of set 4|saint george
# City not found. Skipping...toliary
# Processing Record 39 of set 4|salto
# Processing Record 40 of set 4|ugoofaaru
# City not found. Skipping...tsihombe
# Processing Record 42 of set 4|mandera
# Processing Record 43 of set 4|coquimbo
# Processing Record 44 of set 4|sarangani
# Processing Record 45 of set 4|turbo
# Processing Record 46 of set 4|rio claro
# Processing Record 47 of set 4|christchurch
# Processing Record 48 of set 4|caravelas
# City not found. Skipping...ust-kamchatsk
# Processing Record 50 of set 4|palmer
# Processing Record 0 of set 5|solnechnyy
# Processing Record 1 of set 5|cuicatlan
# Processing Record 2 of set 5|nome
# Processing Record 3 of set 5|pyapon
# Processing Record 4 of set 5|luderitz
# Processing Record 5 of set 5|half moon bay
# Processing Record 6 of set 5|fort nelson
# City not found. Skipping...haapu
# Processing Record 8 of set 5|greystones
# Processing Record 9 of set 5|ponta do sol
# Processing Record 10 of set 5|toktogul
# Processing Record 11 of set 5|san patricio
# Processing Record 12 of set 5|najran
# Processing Record 13 of set 5|laguna
# Processing Record 14 of set 5|logan
# Processing Record 15 of set 5|vestmanna
# Processing Record 16 of set 5|sylacauga
# City not found. Skipping...lolua
# Processing Record 18 of set 5|lasa
# Processing Record 19 of set 5|blackfoot
# Processing Record 20 of set 5|charters towers
# Processing Record 21 of set 5|palang
# Processing Record 22 of set 5|longyearbyen
# Processing Record 23 of set 5|labuan
# Processing Record 24 of set 5|camana
# Processing Record 25 of set 5|veraval
# Processing Record 26 of set 5|tapes
# Processing Record 27 of set 5|gloucester
# Processing Record 28 of set 5|port-cartier
# Processing Record 29 of set 5|souillac
# Processing Record 30 of set 5|mehamn
# Processing Record 31 of set 5|filadelfia
# Processing Record 32 of set 5|jerome
# Processing Record 33 of set 5|xintai
# Processing Record 34 of set 5|pundaguitan
# City not found. Skipping...illoqqortoormiut
# Processing Record 36 of set 5|tsogni
# Processing Record 37 of set 5|danielskuil
# Processing Record 38 of set 5|kijang
# Processing Record 39 of set 5|husavik
# Processing Record 40 of set 5|airai
# Processing Record 41 of set 5|makakilo city
# Processing Record 42 of set 5|sikar
# Processing Record 43 of set 5|evanton
# Processing Record 44 of set 5|namikupa
# Processing Record 45 of set 5|jimo
# Processing Record 46 of set 5|berlevag
# Processing Record 47 of set 5|michigan city
# Processing Record 48 of set 5|ullapool
# Processing Record 49 of set 5|namatanai
# Processing Record 50 of set 5|leningradskiy
# Processing Record 0 of set 6|lompoc
# City not found. Skipping...kamenskoye
# Processing Record 2 of set 6|itarema
# Processing Record 3 of set 6|kathu
# Processing Record 4 of set 6|baker city
# Processing Record 5 of set 6|sol-iletsk
# Processing Record 6 of set 6|magnor
# Processing Record 7 of set 6|pangody
# Processing Record 8 of set 6|cidreira
# Processing Record 9 of set 6|avera
# Processing Record 10 of set 6|semnan
# Processing Record 11 of set 6|myitkyina
# Processing Record 12 of set 6|comodoro rivadavia
# Processing Record 13 of set 6|cheney
# Processing Record 14 of set 6|hohhot
# Processing Record 15 of set 6|libreville
# Processing Record 16 of set 6|san cristobal
# Processing Record 17 of set 6|kirakira
# Processing Record 18 of set 6|alta floresta
# Processing Record 19 of set 6|orange cove
# Processing Record 20 of set 6|merauke
# Processing Record 21 of set 6|pombas
# Processing Record 22 of set 6|atar
# Processing Record 23 of set 6|salamiyah
# Processing Record 24 of set 6|rock sound
# Processing Record 25 of set 6|bethel
# Processing Record 26 of set 6|utinga
# Processing Record 27 of set 6|kananga
# City not found. Skipping...kuche
# Processing Record 29 of set 6|esperance
# Processing Record 30 of set 6|taoudenni
# Processing Record 31 of set 6|bulgan
# Processing Record 32 of set 6|verkhnevilyuysk
# Processing Record 33 of set 6|stykkisholmur
# Processing Record 34 of set 6|slobidka
# Processing Record 35 of set 6|koutiala
# Processing Record 36 of set 6|komsomolskiy
# Processing Record 37 of set 6|coos bay
# Processing Record 38 of set 6|kodiak
# City not found. Skipping...nizhneyansk
# Processing Record 40 of set 6|hambantota
# Processing Record 41 of set 6|havre-saint-pierre
# Processing Record 42 of set 6|usinsk
# Processing Record 43 of set 6|hofn
# Processing Record 44 of set 6|gamba
# Processing Record 45 of set 6|pesochnoye
# Processing Record 46 of set 6|preeceville
# City not found. Skipping...barentsburg
# City not found. Skipping...chagda
# Processing Record 49 of set 6|clyde river
# Processing Record 50 of set 6|kilindoni
# Processing Record 0 of set 7|chifeng
# Processing Record 1 of set 7|bundaberg
# Processing Record 2 of set 7|poum
# Processing Record 3 of set 7|bandarbeyla
# Processing Record 4 of set 7|camacha
# Processing Record 5 of set 7|maniitsoq
# Processing Record 6 of set 7|ico
# Processing Record 7 of set 7|broome
# Processing Record 8 of set 7|rudbar
# Processing Record 9 of set 7|olinda
# City not found. Skipping...amderma
# Processing Record 11 of set 7|hirara
# City not found. Skipping...mys shmidta
# Processing Record 13 of set 7|acapulco
# Processing Record 14 of set 7|zhezkazgan
# Processing Record 15 of set 7|havoysund
# Processing Record 16 of set 7|sinnamary
# Processing Record 17 of set 7|nha trang
# Processing Record 18 of set 7|maple creek
# Processing Record 19 of set 7|new norfolk
# Processing Record 20 of set 7|bilibino
# City not found. Skipping...tumannyy
# Processing Record 22 of set 7|lagunas
# Processing Record 23 of set 7|shuangcheng
# Processing Record 24 of set 7|qui nhon
# Processing Record 25 of set 7|olafsvik
# Processing Record 26 of set 7|college
# Processing Record 27 of set 7|waingapu
# Processing Record 28 of set 7|hay river
# Processing Record 29 of set 7|mineiros
# Processing Record 30 of set 7|sabla
# Processing Record 31 of set 7|beringovskiy
# Processing Record 32 of set 7|kavaratti
# Processing Record 33 of set 7|ngawen
# Processing Record 34 of set 7|portland
# City not found. Skipping...marcona
# Processing Record 36 of set 7|sinop
# City not found. Skipping...bargal
# Processing Record 38 of set 7|dicabisagan
# Processing Record 39 of set 7|port hedland
# Processing Record 40 of set 7|astoria
# Processing Record 41 of set 7|la rioja
# Processing Record 42 of set 7|preobrazheniye
# Processing Record 43 of set 7|pizarro
# Processing Record 44 of set 7|naze
# Processing Record 45 of set 7|sechura
# Processing Record 46 of set 7|deputatskiy
# Processing Record 47 of set 7|thaba-tseka
# Processing Record 48 of set 7|jieshi
# Processing Record 49 of set 7|bambous virieux
# Processing Record 50 of set 7|huanren
# Processing Record 0 of set 8|kyzyl-suu
# Processing Record 1 of set 8|asyut
# Processing Record 2 of set 8|ust-tsilma
# Processing Record 3 of set 8|kuantan
# Processing Record 4 of set 8|dabat
# Processing Record 5 of set 8|mahalapye
# Processing Record 6 of set 8|narsaq
# Processing Record 7 of set 8|askino
# Processing Record 8 of set 8|wakkanai
# City not found. Skipping...burica
# Processing Record 10 of set 8|madimba
# Processing Record 11 of set 8|awjilah
# Processing Record 12 of set 8|riberalta
# Processing Record 13 of set 8|arman
# Processing Record 14 of set 8|inhambane
# Processing Record 15 of set 8|paita
# Processing Record 16 of set 8|novoorsk
# City not found. Skipping...bengkalis
# Processing Record 18 of set 8|tigil
# Processing Record 19 of set 8|aras
# Processing Record 20 of set 8|bathsheba
# Processing Record 21 of set 8|muana
# Processing Record 22 of set 8|waitara
# Processing Record 23 of set 8|taltal
# Processing Record 24 of set 8|kostomuksha
# Processing Record 25 of set 8|conde
# Processing Record 26 of set 8|general roca
# Processing Record 27 of set 8|broken hill
# Processing Record 28 of set 8|san andres
# Processing Record 29 of set 8|elizabeth city
# City not found. Skipping...daxian
# Processing Record 31 of set 8|puerto varas
# Processing Record 32 of set 8|tilichiki
# Processing Record 33 of set 8|turukhansk
# Processing Record 34 of set 8|dickinson
# Processing Record 35 of set 8|mayumba
# Processing Record 36 of set 8|bereda
# Processing Record 37 of set 8|krasnoselkup
# Processing Record 38 of set 8|ayia galini
# Processing Record 39 of set 8|mackay
# Processing Record 40 of set 8|sri aman
# Processing Record 41 of set 8|nacala
# Processing Record 42 of set 8|beloha
# City not found. Skipping...zachagansk
# Processing Record 44 of set 8|rawatsar
# Processing Record 45 of set 8|labuhan
# Processing Record 46 of set 8|neryungri
# Processing Record 47 of set 8|troitskoye
# Processing Record 48 of set 8|hasilpur
# Processing Record 49 of set 8|am timan
# City not found. Skipping...cockburn harbour
# Processing Record 0 of set 9|arcelia
# Processing Record 1 of set 9|vila franca do campo
# Processing Record 2 of set 9|rundu
# Processing Record 3 of set 9|roma
# Processing Record 4 of set 9|alangulam
# Processing Record 5 of set 9|forbes
# Processing Record 6 of set 9|bemidji
# Processing Record 7 of set 9|rawson
# Processing Record 8 of set 9|walvis bay
# Processing Record 9 of set 9|bolgatanga
# Processing Record 10 of set 9|swinford
# Processing Record 11 of set 9|aklavik
# Processing Record 12 of set 9|kropotkin
# Processing Record 13 of set 9|peniche
# Processing Record 14 of set 9|mezen
# Processing Record 15 of set 9|havelock
# Processing Record 16 of set 9|wanning
# Processing Record 17 of set 9|sobolevo
# Processing Record 18 of set 9|khani
# Processing Record 19 of set 9|plettenberg bay
# Processing Record 20 of set 9|lichinga
# Processing Record 21 of set 9|santa cruz
# Processing Record 22 of set 9|pauini
# City not found. Skipping...yirol
# Processing Record 24 of set 9|jutai
# Processing Record 25 of set 9|kavieng
# Processing Record 26 of set 9|srednekolymsk
# Processing Record 27 of set 9|vrangel
# Processing Record 28 of set 9|tatarskaya pishlya
# Processing Record 29 of set 9|ulaanbaatar
# Processing Record 30 of set 9|hualmay
# Processing Record 31 of set 9|herat
# Processing Record 32 of set 9|sioux lookout
# Processing Record 33 of set 9|progreso
# Processing Record 34 of set 9|castlecomer
# City not found. Skipping...haibowan
# Processing Record 36 of set 9|yeppoon
# City not found. Skipping...paradwip
# Processing Record 38 of set 9|ongandjera
# Processing Record 39 of set 9|diffa
# Processing Record 40 of set 9|narasannapeta
# Processing Record 41 of set 9|pevek
# Processing Record 42 of set 9|butembo
# Processing Record 43 of set 9|emba
# Processing Record 44 of set 9|saint anthony
# Processing Record 45 of set 9|zabol
# Processing Record 46 of set 9|bonfim
# City not found. Skipping...buariki
# City not found. Skipping...saleaula
# Processing Record 49 of set 9|lovozero
# Processing Record 50 of set 9|rumphi
# Processing Record 0 of set 10|lufkin
# Processing Record 1 of set 10|qasigiannguit
# Processing Record 2 of set 10|gunjur
# Processing Record 3 of set 10|kousseri
# Processing Record 4 of set 10|dunmore town
# Processing Record 5 of set 10|santa teresa
# Processing Record 6 of set 10|alice springs
# Processing Record 7 of set 10|cancun
# Processing Record 8 of set 10|south bend
# Processing Record 9 of set 10|suez
# City not found. Skipping...sorvag
# Processing Record 11 of set 10|calatayud
# Processing Record 12 of set 10|tual
# City not found. Skipping...louisbourg
# Processing Record 14 of set 10|gillette
# Processing Record 15 of set 10|russas
# Processing Record 16 of set 10|wuwei
# Processing Record 17 of set 10|bardiyah
# Processing Record 18 of set 10|altay
# Processing Record 19 of set 10|dalbandin
# Processing Record 20 of set 10|kununurra
# Processing Record 21 of set 10|sistranda
# Processing Record 22 of set 10|bolobo
# Processing Record 23 of set 10|innisfail
# Processing Record 24 of set 10|muisne
# Processing Record 25 of set 10|okha
# Processing Record 26 of set 10|trelew
# Processing Record 27 of set 10|codo
# Processing Record 28 of set 10|finale ligure
# Processing Record 29 of set 10|mahebourg
# Processing Record 30 of set 10|ketchikan
# Processing Record 31 of set 10|yumen
# City not found. Skipping...tidore
# Processing Record 33 of set 10|nevelsk
# Processing Record 34 of set 10|tomatlan
# Processing Record 35 of set 10|palauig
# Processing Record 36 of set 10|codrington
# Processing Record 37 of set 10|mataram
# Processing Record 38 of set 10|guerrero negro
# Processing Record 39 of set 10|bud
# Processing Record 40 of set 10|beyneu
# Processing Record 41 of set 10|sao joao da barra
# Processing Record 42 of set 10|lorengau
# Processing Record 43 of set 10|coihaique
# Processing Record 44 of set 10|san pedro
# Processing Record 45 of set 10|murray bridge
# Processing Record 46 of set 10|da nang
# Processing Record 47 of set 10|dhidhdhoo
# Processing Record 48 of set 10|katangli
# City not found. Skipping...formoso do araguaia
# Processing Record 50 of set 10|buala
# City not found. Skipping...igarape-miri
# Processing Record 1 of set 11|behshahr
# Processing Record 2 of set 11|hwange
# Processing Record 3 of set 11|thio
# Processing Record 4 of set 11|san policarpo
# Processing Record 5 of set 11|saryg-sep
# Processing Record 6 of set 11|mugango
# Processing Record 7 of set 11|platteville
# City not found. Skipping...attawapiskat
# Processing Record 9 of set 11|tongliao
# Processing Record 10 of set 11|kenitra
# Processing Record 11 of set 11|licata
# Processing Record 12 of set 11|astana
# Processing Record 13 of set 11|dongli
# Processing Record 14 of set 11|sao felix do xingu
# Processing Record 15 of set 11|moreira
# Processing Record 16 of set 11|dapaong
# Processing Record 17 of set 11|kitob
# Processing Record 18 of set 11|richards bay
# Processing Record 19 of set 11|kangaatsiaq
# Processing Record 20 of set 11|khotynets
# Processing Record 21 of set 11|itapirapua
# Processing Record 22 of set 11|salinopolis
# Processing Record 23 of set 11|severnyy
# Processing Record 24 of set 11|lumby
# Processing Record 25 of set 11|pandan
# City not found. Skipping...barawe
# City not found. Skipping...tasbuget
# Processing Record 28 of set 11|fare
# Processing Record 29 of set 11|yashan
# Processing Record 30 of set 11|durusu
# Processing Record 31 of set 11|maracaju
# Processing Record 32 of set 11|grand falls
# Processing Record 33 of set 11|auki
# Processing Record 34 of set 11|kokemaki
# Processing Record 35 of set 11|san jeronimo
# Processing Record 36 of set 11|antibes
# Processing Record 37 of set 11|asfi
# Processing Record 38 of set 11|port augusta
# City not found. Skipping...wulanhaote
# Processing Record 40 of set 11|yarada
# Processing Record 41 of set 11|biak
# Processing Record 42 of set 11|kemin
# Processing Record 43 of set 11|paamiut
# Processing Record 44 of set 11|muroto
# Processing Record 45 of set 11|saalfeld
# Processing Record 46 of set 11|lethem
# Processing Record 47 of set 11|tecoanapa
# Processing Record 48 of set 11|moussoro
# Processing Record 49 of set 11|madingou
# Processing Record 50 of set 11|vila velha
# Processing Record 0 of set 12|xining
# Processing Record 1 of set 12|taksimo
# Processing Record 2 of set 12|riyadh
# Processing Record 3 of set 12|fort wellington
# Processing Record 4 of set 12|kieta
# Processing Record 5 of set 12|erchie
# Processing Record 6 of set 12|miyako
# Processing Record 7 of set 12|belmonte
# Processing Record 8 of set 12|saint-joseph
# Processing Record 9 of set 12|dunedin
# City not found. Skipping...karaul
# Processing Record 11 of set 12|odweyne
# Processing Record 12 of set 12|manta
# Processing Record 13 of set 12|te anau
# Processing Record 14 of set 12|bambanglipuro
# Processing Record 15 of set 12|buckeye
# Processing Record 16 of set 12|kamskiye polyany
# Processing Record 17 of set 12|ardee
# Processing Record 18 of set 12|sorland
# Processing Record 19 of set 12|gbarnga
# Processing Record 20 of set 12|amapa
# Processing Record 21 of set 12|sibolga
# Processing Record 22 of set 12|mount gambier
# Processing Record 23 of set 12|oktyabrskoye
# Processing Record 24 of set 12|dinghai
# Processing Record 25 of set 12|ca mau
# Processing Record 26 of set 12|port blair
# Processing Record 27 of set 12|dolores
# Processing Record 28 of set 12|spas-demensk
# Processing Record 29 of set 12|limbang
# Processing Record 30 of set 12|rawlins
# Processing Record 31 of set 12|nova odesa
# Processing Record 32 of set 12|buraydah
# Processing Record 33 of set 12|bengkulu
# Processing Record 34 of set 12|dauriya
# City not found. Skipping...samalaeulu
# Processing Record 36 of set 12|saint-pierre
#  -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#!mkdir weather_CSV

city_dic={'City':city_data,
          'Lat':coord_lat,
          'lng':coord_lon,
          'Max Temp':main_max_temp,
          'Humidity':humidity,
          'Cloudiness':cloudiness,
          'Wind Speed':wind_speed,
          'Country':country,
          'Date':dt}
city_data_df=pd.DataFrame(city_dic)
city_data_df

#export the city data into .CSV
city_data_df.to_csv('weather_CSV/weather_data.csv')

#display the data frame.
city_data_df
# Out:
#                City      Lat       lng  Max Temp  Humidity  Cloudiness  \
# 0          hermanus -34.4187   19.2345     73.00        61           2
# 1         cape town -33.9258   18.4232     72.00        78          75
# 2    saint-philippe -21.3585   55.7679     78.80        73           0
# 3        bukachacha  52.9833  116.9167     21.83        93         100
# 4          thompson  55.7435  -97.8558     19.40        53          20
# ..              ...      ...       ...       ...       ...         ...
# 542      nova odesa  47.3078   31.7851     39.16        94          97
# 543        buraydah  26.3260   43.9750     66.20        42           0
# 544        bengkulu  -3.8004  102.2655     76.23        81         100
# 545         dauriya  49.9333  116.8667     28.60        74           1
# 546    saint-pierre -21.3393   55.4781     78.80        73           0
#
#      Wind Speed Country        Date
# 0          3.00      ZA  1615662263
# 1          9.22      ZA  1615662253
# 2         13.80      RE  1615662264
# 3          1.88      RU  1615662264
# 4         16.11      CA  1615662265
# ..          ...     ...         ...
# 542        5.57      UA  1615662461
# 543        6.91      SA  1615662401
# 544        5.10      ID  1615662461
# 545        7.70      RU  1615662461
# 546       13.80      RE  1615662275
#
# [547 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#sortting all the values under humidity 
humidity_df=city_data_df.sort_values('Humidity',ascending=False)
humidity_df
#This step needs to be skiped since there is no values over 100 under humidity.
# Out:
#               City      Lat       lng  Max Temp  Humidity  Cloudiness  \
# 173    wagga wagga -35.1167  147.3667     57.99       100          90
# 540        limbang   4.7500  115.0000     75.20       100          75
# 533  mount gambier -37.8333  140.7667     41.00       100          40
# 437      kununurra -15.7667  128.7333     78.80       100          40
# 529        sorland  67.6670   12.6934     37.40       100          40
# ..             ...      ...       ...       ...       ...         ...
# 39           adrar  20.5022  -10.0711     74.21        11           0
# 382     bolgatanga  10.7856   -0.8514     89.87        11         100
# 256           atar  20.5169  -13.0499     87.80         9           0
# 409          diffa  13.3154   12.6113     88.70         8          47
# 509       moussoro  13.6408   16.4901     93.76         7           0
#
#      Wind Speed Country        Date
# 173       11.50      AU  1615662325
# 540        2.30      MY  1615662460
# 533        4.61      AU  1615662457
# 437        5.84      AU  1615662420
# 529        4.61      NO  1615662441
# ..          ...     ...         ...
# 39         8.99      MR  1615662277
# 382        5.19      GH  1615662400
# 256        9.22      MR  1615662139
# 409        7.29      NE  1615662410
# 509        9.80      TD  1615662448
#
# [547 rows x 9 columns]

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# def imganalisys(columnX,columnY):
#     plt.scatter(city_data_df[""], city_data_df["columnY"], marker="o", s=15)
#     plt.xlabel("Latitude")
#     plt.grid(True)
#     return

# %%
#!mkdir figure

#imganalisys('Lat','Max Temp')

plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, s=30)
plt.xlabel("Latitude")
plt.title(f'City Latitude vs. Max Temperature {time.strftime("%m / %d / %y")}')
plt.ylabel("Max. Temperature (F)")

plt.grid(True)
plt.savefig("figure/plotLatitudeVsTemperaturePlot.png")
print("Plot analysis image: the change in temperatures is clearly visible as the location move toward the equator temperatures start to rise but as the move away from the equator, temperatures start to decent once more describing a parabola")
plt.show()
# Out:
# Plot analysis image: the change in temperatures is clearly visible as the location move toward the equator temperatures start to rise but as the move away from the equator, temperatures start to decent once more describing a parabola

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#imganalisys('Lat','Humidity')
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolor="black", linewidths=1, marker="o", 
            alpha=0.9, s=30)
plt.xlabel("Latitude")
plt.title(f'City Latitude vs. Humidity {time.strftime("%m / %d / %y")}')
plt.ylabel("Humidity(%)")

plt.grid(True)
plt.savefig("figure/plotLatitudeVsHumidityPlot.png")
print("Plot analysis image: the humidity levels change as the location moves from the equator. The closer to the equator the more humid the environment.")
plt.show()
# Out:
# Plot analysis image: the humidity levels change as the location moves from the equator. The closer to the equator the more humid the environment.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolor="black", linewidths=1, marker="o", 
            alpha=0.9, s=30)

plt.title(f'Latitude vs. Cloudiness Plot {time.strftime("%m / %d / %y")}')
plt.ylabel("Cloudiness(%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("figure/plotLatitudeVsCloudinessPlot.png")
print("Plot analysis image:There seems to be not a clear relationship between the formation of clouds and the geographic location.")
plt.show()
# Out:
# Plot analysis image:There seems to be not a clear relationship between the formation of clouds and the geographic location.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolor="black", linewidths=1, marker="o", 
            alpha=0.9, s=30)

plt.title(f'Latitude vs. Wind Speed Plot {time.strftime("%m / %d / %y")}')
plt.ylabel("wind speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("figure/plotLatitudeVsWindSpeedPlot.png")
print("Plot analysis image: there is a bigger difference between wind speed in the northern hemisphere and the southern hemisphere. Wind speeds are greater in the north than the south but the variation in speed is greater in the southern hemisphere. ")
plt.show()
# Out:
# Plot analysis image: there is a bigger difference between wind speed in the northern hemisphere and the southern hemisphere. Wind speeds are greater in the north than the south but the variation in speed is greater in the southern hemisphere.

# %% [markdown]
# ## Linear Regression

# %%
#northen lat will provided all cities over the Ecuador line.
nh_df=city_data_df.loc[city_data_df["Lat"]>0.0]
#nh_df
mtN_df=nh_df.sort_values('Max Temp',ascending=False)
mtN_df.reset_index(inplace=True)
mtN_df
# Out:
#      index           City      Lat       lng  Max Temp  Humidity  Cloudiness  \
# 0      373        arcelia  18.2833 -100.2667    101.89        17           0
# 1      450       tomatlan  19.9333 -105.2500    100.00        16           0
# 2      422       kousseri  12.0769   15.0306     98.60        18           0
# 3      188      cuicatlan  17.8000  -96.9667     94.30        24           0
# 4      509       moussoro  13.6408   16.4901     93.76         7           0
# ..     ...            ...      ...       ...       ...       ...         ...
# 359     98         dikson  73.5069   80.5464    -21.15        96         100
# 360    322    deputatskiy  69.3000  139.9000    -24.52        75           0
# 361    361   krasnoselkup  65.7000   82.4667    -24.61        89           0
# 362    398  srednekolymsk  67.4500  153.6833    -25.89       100          92
# 363    357     turukhansk  65.8167   87.9833    -31.27        95           0
#
#      Wind Speed Country        Date
# 0          4.63      MX  1615662397
# 1          8.55      MX  1615662425
# 2          3.44      CM  1615662415
# 3          3.98      MX  1615662330
# 4          9.80      TD  1615662448
# ..          ...     ...         ...
# 359       16.98      RU  1615662280
# 360        2.71      RU  1615662378
# 361       10.51      RU  1615662392
# 362        1.83      RU  1615662406
# 363        6.31      RU  1615662391
#
# [364 rows x 10 columns]

# %%
#Southern lat will provided all cities under the Ecuador line.
sh_df=city_data_df.loc[city_data_df["Lat"]<0.0]
#sh_df
mt_df=sh_df.sort_values('Max Temp',ascending=False)
mt_df.reset_index(inplace=True)
mt_df
# Out:
#      index           City      Lat       lng  Max Temp  Humidity  Cloudiness  \
# 0      105  pozo colorado -23.4923  -58.7972     99.59        24         100
# 1      183      rio claro -22.4114  -47.5614     91.40        35          40
# 2      341          paita  -5.0892  -81.1144     91.40        49           0
# 3      394     santa cruz -17.8000  -63.1667     91.40        55          75
# 4       84       eldorado -23.7869  -54.2836     91.27        36           0
# ..     ...            ...      ...       ...       ...       ...         ...
# 178     13      tuatapere -46.1333  167.6833     48.00        89           1
# 179     69        ushuaia -54.8000  -68.3000     44.60        70          75
# 180    298    new norfolk -42.7826  147.0587     43.00        66           6
# 181    146    colquechaca -18.6667  -66.0167     41.40        62          35
# 182    533  mount gambier -37.8333  140.7667     41.00       100          40
#
#      Wind Speed Country        Date
# 0          2.75      PY  1615662299
# 1          4.61      BR  1615662106
# 2         12.66      PE  1615662088
# 3          4.61      BO  1615662404
# 4          4.00      BR  1615662229
# ..          ...     ...         ...
# 178        1.01      NZ  1615662268
# 179       37.98      AR  1615662093
# 180        2.86      AU  1615662369
# 181        7.14      BO  1615662315
# 182        4.61      AU  1615662457
#
# [183 rows x 10 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = nh_df['Lat']
y_values = nh_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,10),fontsize=15,color="red")
plt.title(f'Northern Hemisphere - Max Temp vs. Latitude Linear Regression {time.strftime("%m / %d / %y")}')
plt.xlabel('Lat')
plt.ylabel('Max Temp')
print(f"The r-squared is: {rvalue**2}")
plt.savefig("figure/plotNorthenHemisphere.png")
print("for this side os the sphere there is a strong negative correlation between latitude and max temperature for northern hemisphere as we move away from the ecuator.")
plt.show()
# Out:
# The r-squared is: 0.7953581182885152
# for this side os the sphere there is a strong negative correlation between latitude and max temperature for northern hemisphere as we move away from the ecuator.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = sh_df['Lat']
y_values = sh_df['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,50),fontsize=15,color="red")
plt.title(f'Southern Hemisphere - Max Temp vs. Latitude Linear Regression {time.strftime("%m / %d / %y")}')
plt.xlabel('Lat')
plt.ylabel('Max Temp')
print(f"The r-squared is: {rvalue**2}")
plt.savefig("figure/plotSothernHemisphere.png")
print("for this side os the sphere there is a strong Positive correlation between latitude and max temperature for northern hemisphere as we move in direction the ecuator.")

plt.show()
# Out:
# The r-squared is: 0.3843347706769695
# for this side os the sphere there is a strong Positive correlation between latitude and max temperature for northern hemisphere as we move in direction the ecuator.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = nh_df['Lat']
y_values = nh_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(45,15),fontsize=15,color="red")
plt.title(f'Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression {time.strftime("%m / %d / %y")}')
plt.xlabel('Lat')
plt.ylabel('Humidity')
print(f"The r-squared is: {rvalue**2}")
plt.savefig("figure/plotNorthenHemisphereHumidity.png")
print("There is a moderate positive correlation between latitude and humidity")
plt.show()
# Out:
# The r-squared is: 0.0672145333160425
# There is a moderate positive correlation between latitude and humidity

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = sh_df['Lat']
y_values = sh_df['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-45,15),fontsize=15,color="red")
plt.title(f'Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression {time.strftime("%m / %d / %y")}')
plt.xlabel('Lat')
plt.ylabel('Humidity')
print(f"The r-squared is: {rvalue**2}")
plt.savefig("figure/plotSouthernHemisphereHumidityS.png")
print("There is a moderate positive correlation between latitude and humidity")
plt.show()
# Out:
# The r-squared is: 0.029444853085430996
# There is a moderate positive correlation between latitude and humidity

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = nh_df['Lat']
y_values = nh_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(30,20),fontsize=15,color="red")
plt.title(f'Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression {time.strftime("%m / %d / %y")}')
plt.xlabel('Lat')
plt.ylabel('Cloudiness')
print(f"The r-squared is: {rvalue**2}")
plt.savefig("figure/plotNorthenHemisphereCloudiness.png")
print(" There is a weak positive correlation between latitude and cloudiness for southern hemisphere")
plt.show()
# Out:
# The r-squared is: 0.023615793809185225
#  There is a weak positive correlation between latitude and cloudiness for southern hemisphere

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = sh_df['Lat']
y_values = sh_df['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,15),fontsize=15,color="red")
plt.title(f'Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression {time.strftime("%m / %d / %y")}')
plt.xlabel('Lat')
plt.ylabel('Cloudiness')
print(f"The r-squared is: {rvalue**2}")
plt.savefig("figure/plotSothernHemisphereCloudinessS.png")
print(" There is a strong positive correlation between latitude and cloudiness for southern hemisphere")
plt.show()
# Out:
# The r-squared is: 0.15502837509551362
#  There is a strong positive correlation between latitude and cloudiness for southern hemisphere

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = nh_df['Lat']
y_values = nh_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,17.5),fontsize=15,color="red")
plt.title(f'Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression {time.strftime("%m / %d / %y")}')
plt.xlabel('Lat')
plt.ylabel('Wind Speed (mph)')
print(f"The r-squared is: {rvalue**2}")
plt.savefig("figure/plotNorthenHemisphereWS.png")
print("latitud related")
print("There is a weak positive correlation between latitude and wind speed for southern hemisphere.")
plt.show()
# Out:
# The r-squared is: 0.032900276904357165
# latitud related
# There is a weak positive correlation between latitude and wind speed for southern hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = sh_df['Lat']
y_values = sh_df['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,15),fontsize=15,color="red")
plt.title(f'Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression {time.strftime("%m / %d / %y")}')
plt.xlabel('Lat')
plt.ylabel('Wind Speed(mph)')
print(f"The r-squared is: {rvalue**2}")
plt.savefig("figure/plotSothernHemisphereWSS.png")
print("There is a weak negative correlation between latitude and wind speed for southern hemisphere.")
plt.show()
# Out:
# The r-squared is: 0.07334546151289112
# There is a weak negative correlation between latitude and wind speed for southern hemisphere.
